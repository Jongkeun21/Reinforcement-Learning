# %% [markdown]
# ## Model-based Reinforcement Learning

# %%
import tensorflow as tf
import numpy as np

tf.logging.set_verbosity(tf.logging.ERROR)

# %%
import gym

env = gym.make('CartPole-v0')

# %% [markdown]
# ### ***Hyper parameters***

# %%
# H: number of hidden layer neurons
# gamma: discount factor
# decay_rate: decay factor for RMSProp leaky sum of grad^2
# resume: resume from previous checkpoint?
# model_bs: batch size when learning from model
# real_bs: batch size when learning from real environment

H = 8
lr = 1e-2
gamma = 0.99
decay_rate = 0.99
resume = False
model_bs = 3
real_bs = 3

# %% [markdown]
# ### ***Policy gradient network***

# %%
tf.reset_default_graph()
observations = tf.placeholder(shape=[None,4], dtype=tf.float32, name='input_x')

W1 = tf.get_variable(shape=[4,H], name='W1', initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations, W1))

W2 = tf.get_variable(shape=[H,1], name='W2', initializer=tf.contrib.layers.xavier_initializer())
score = tf.nn.relu(tf.matmul(layer1, W2))

probability = tf.nn.sigmoid(score)

tvars = tf.trainable_variables()
input_y = tf.placeholder(shape=[None,1], dtype=tf.float32, name='input_y')
advantages = tf.placeholder(dtype=tf.float32, name='reward_signal')

loglik = tf.log(input_y*(input_y-probability)+(1-input_y)*(input_y+probability))
loss = -tf.reduce_mean(loglik*advantages)
newGrads = tf.gradients(loss, tvars)

adam = tf.train.AdamOptimizer(learning_rate=lr)
W1Grad = tf.placeholder(tf.float32, name='batch_grad1')
W2Grad = tf.placeholder(tf.float32, name='batch_grad2')
batchGrad = [W1Grad, W2Grad]
updateGrads = adam.apply_gradients(zip(batchGrad, tvars))

# %% [markdown]
# ### ***Model network***

# %%
mH = 256
input_data = tf.placeholder(shape=[None,5], dtype=tf.float32)
previous_state = tf.placeholder(shape=[None,5], dtype=tf.float32, name='previous_state')

W1M = tf.get_variable(shape=[5,mH], name='W1M', initializer=tf.contrib.layers.xavier_initializer())
B1M = tf.Variable(tf.zeros([mH]), name='B1M')
layer1M = tf.nn.relu(tf.matmul(previous_state, W1M)+B1M)

W2M = tf.get_variable(shape=[mH,mH], name='W2M', initializer=tf.contrib.layers.xavier_initializer())
B2M = tf.Variable(tf.zeros([mH]), name='B2M')
layer2M = tf.nn.relu(tf.matmul(layer1M, W2M)+B2M)

WO = tf.get_variable(shape=[mH,4], name='WO', initializer=tf.contrib.layers.xavier_initializer())
WR = tf.get_variable(shape=[mH,1], name='WR', initializer=tf.contrib.layers.xavier_initializer())
WD = tf.get_variable(shape=[mH,1], name='WD', initializer=tf.contrib.layers.xavier_initializer())

bO = tf.Variable(tf.zeros([4]), name='bO')
bR = tf.Variable(tf.zeros([1]), name='bR')
bD = tf.Variable(tf.zeros([1]), name='bD')

predicted_observation = tf.matmul(layer2M, WO, name='predicted_observation')+bO
predicted_reward = tf.matmul(layer2M, WR, name='predicted_reward')+bR
predicted_done = tf.sigmoid(tf.matmul(layer2M, WD, name='predicted_done')+bD)

true_observation = tf.placeholder(shape=[None,4], dtype=tf.float32, name='true_observation')
true_reward = tf.placeholder(shape=[None,1], dtype=tf.float32, name='true_reward')
true_done = tf.placeholder(shape=[None,1], dtype=tf.float32, name='true_done')

predicted_state = tf.concat([predicted_observation, predicted_reward, predicted_done], 1)

observation_loss = tf.square(true_observation-predicted_observation)
reward_loss = tf.square(true_reward-predicted_reward)
done_loss = tf.multiply(predicted_done, true_done)+tf.multiply(1-predicted_done, 1-true_done)
done_loss = -tf.log(done_loss)

model_loss = tf.reduce_mean(observation_loss+done_loss+reward_loss)
model_adam = tf.train.AdamOptimizer(learning_rate=lr)
updateModel = model_adam.minimize(model_loss)

# %% [markdown]
# ### ***Helper-functions***

# %%
# initializer gradBuffer
def resetGradBuffer(gradBuffer) :
    for idx, grad in enumerate(gradBuffer) :
        gradBuffer[idx] = grad*0
        
    return gradBuffer

# get discounting reward
def discount_rewards(r) :
    discounted = np.zeros_like(r)
    running_add = 0
    
    for t in reversed(range(0, r.size)) :
        running_add = running_add*gamma+r[t]
        discounted[t] = running_add
        
    return discounted

# to produce a new state when given a previous state and action
def stepModel(sess, xs, action) :
    toFeed = np.reshape(np.hstack([xs[-1][0], np.array(action)]), [1,5])
    myPredict = sess.run([predicted_state], feed_dict={previous_state: toFeed})
    reward = myPredict[0][:,4]
    
    observation = myPredict[0][:,0:4]
    observation[:,0] = np.clip(observation[:,0], -2.4, 2.4)
    observation[:,2] = np.clip(observation[:,2], -0.4, 0.4)
    
    doneP = np.clip(myPredict[0][:,5], 0, 1)
    
    if doneP > 0.1 or len(xs) >= 300 :
        done = True
    else :
        done = False
        
    return observation, reward, done

# %% [markdown]
# ### ***Training***

# %%
xs, drs, ys, ds = [], [], [], []
running_reward = None
reward_sum = 0
episode_number = 1
EPOCHS = 5000
real_episodes = 1
init = tf.global_variables_initializer()
batch_size = real_bs

drawFromModel = False
trainTheModel = True
trainThePolicy = False
switch_point = 1

with tf.Session() as sess :
    rendering = False
    sess.run(init)
    observation = env.reset()
    x = observation
    gradBuffer = sess.run(tvars)
    gradBuffer = resetGradBuffer(gradBuffer)
    
    while episode_number <= EPOCHS :
        if (reward_sum/batch_size > 150 and not drawFromModel) or rendering :
            rendering = True
            
        x = np.reshape(observation, [1,4])
        
        tfprob = sess.run(probability, feed_dict={observations: x})
        action = 1 if np.random.uniform() < tfprob else 0
        
        xs.append(x)
        
        y = 0 if action else 1
        ys.append(y)
        
        if not drawFromModel :
            observation, reward, done, info = env.step(action)
        else :
            observation, reward, done = stepModel(sess, xs, action)
            
        reward_sum += reward
        
        ds.append(done*1)
        drs.append(reward)
        
        if done :
            if not drawFromModel :
                real_episodes += 1
                
            episode_number += 1
            
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            epd = np.vstack(ds)
            xs, ys, drs, ds = [], [], [], []
            
            if trainTheModel :
                actions = np.array([np.abs(y-1) for y in epy][:-1])
                state_prevs = epx[:-1,:]
                state_prevs = np.hstack([state_prevs, actions])
                
                state_nexts = epx[1:,:]
                rewards = np.array(epr[1:,:])
                dones = np.array(epd[1:,:])
                
                state_nextsAll = np.hstack([state_nexts, rewards, dones])
                
                feed_dict = {previous_state: state_prevs, true_observation: state_nexts, true_done: dones, true_reward: rewards}
                loss, pState, _ = sess.run([model_loss, predicted_state, updateModel], feed_dict=feed_dict)
                
            if trainThePolicy :
                discounted_epr = discount_rewards(epr).astype('float32')
                discounted_epr -= np.mean(discounted_epr)
                discounted_epr /= np.std(discounted_epr)
                
                tGrad = sess.run(newGrads, feed_dict={observations: epx, input_y: epy, advantages: discounted_epr})
                
                if np.sum(tGrad[0]==tGrad[0]) == 0 :
                    break
                    
                for idx, grad in enumerate(tGrad) :
                    gradBuffer[idx] += grad
                    
            if switch_point+batch_size == episode_number :
                switch_point = episode_number
                
                if trainThePolicy :
                    sess.run(updateGrads, feed_dict={W1Grad: gradBuffer[0], W2Grad: gradBuffer[1]})
                    gradBuffer = resetGradBuffer(gradBuffer)
                    
                running_reward = reward_sum if running_reward is None else running_reward*0.99+reward_sum*0.01
                
                if not drawFromModel :
                    print("World Perf: Episode %f. Reward %f. action %f. mean reward %f." %(real_episodes, reward_sum/real_bs, action, running_reward/real_bs))
                    
                    if reward_sum/batch_size > 200 :
                        break
                        
                reward_sum = 0
                
                if episode_number > 100 :
                    drawFromModel = not drawFromModel
                    trainTheModel = not trainTheModel
                    trainThePolicy = not trainThePolicy
                    
            if drawFromModel :
                observation = np.random.uniform(-0.1, 0.1, [4])
                batch_size = model_bs
            else :
                observation = env.reset()
                batch_size = real_bs
                
print('\nReal episodes is : ', real_episodes)
# Out:
# World Perf: Episode 4.000000. Reward 20.000000. action 1.000000. mean reward 20.000000.
# World Perf: Episode 7.000000. Reward 28.000000. action 1.000000. mean reward 20.080000.
# World Perf: Episode 10.000000. Reward 35.000000. action 0.000000. mean reward 20.229200.
# World Perf: Episode 13.000000. Reward 21.333333. action 1.000000. mean reward 20.240241.
# World Perf: Episode 16.000000. Reward 19.333333. action 0.000000. mean reward 20.231172.
# World Perf: Episode 19.000000. Reward 25.000000. action 0.000000. mean reward 20.278861.
# World Perf: Episode 22.000000. Reward 19.666667. action 1.000000. mean reward 20.272739.
# World Perf: Episode 25.000000. Reward 17.666667. action 0.000000. mean reward 20.246678.
# World Perf: Episode 28.000000. Reward 23.666667. action 1.000000. mean reward 20.280878.
# World Perf: Episode 31.000000. Reward 28.333333. action 0.000000. mean reward 20.361402.
# World Perf: Episode 34.000000. Reward 14.666667. action 1.000000. mean reward 20.304455.
# World Perf: Episode 37.000000. Reward 19.333333. action 1.000000. mean reward 20.294744.
# World Perf: Episode 40.000000. Reward 17.333333. action 1.000000. mean reward 20.265130.
# World Perf: Episode 43.000000. Reward 50.666667. action 0.000000. mean reward 20.569145.
# World Perf: Episode 46.000000. Reward 38.666667. action 1.000000. mean reward 20.750120.
# World Perf: Episode 49.000000. Reward 33.000000. action 0.000000. mean reward 20.872619.
# World Perf: Episode 52.000000. Reward 19.000000. action 1.000000. mean reward 20.853893.
# World Perf: Episode 55.000000. Reward 24.666667. action 1.000000. mean reward 20.892021.
# World Perf: Episode 58.000000. Reward 25.333333. action 1.000000. mean reward 20.936434.
# World Perf: Episode 61.000000. Reward 24.333333. action 0.000000. mean reward 20.970403.
# World Perf: Episode 64.000000. Reward 20.333333. action 1.000000. mean reward 20.964032.
# World Perf: Episode 67.000000. Reward 16.333333. action 0.000000. mean reward 20.917725.
# World Perf: Episode 70.000000. Reward 27.333333. action 1.000000. mean reward 20.981881.
# World Perf: Episode 73.000000. Reward 15.333333. action 0.000000. mean reward 20.925396.
# World Perf: Episode 76.000000. Reward 18.333333. action 0.000000. mean reward 20.899475.
# World Perf: Episode 79.000000. Reward 17.666667. action 1.000000. mean reward 20.867147.
# World Perf: Episode 82.000000. Reward 29.666667. action 0.000000. mean reward 20.955142.
# World Perf: Episode 85.000000. Reward 21.000000. action 0.000000. mean reward 20.955591.
# World Perf: Episode 88.000000. Reward 33.333333. action 0.000000. mean reward 21.079368.
# World Perf: Episode 91.000000. Reward 13.333333. action 0.000000. mean reward 21.001908.
# World Perf: Episode 94.000000. Reward 13.333333. action 1.000000. mean reward 20.925222.
# World Perf: Episode 97.000000. Reward 19.000000. action 0.000000. mean reward 20.905970.
# World Perf: Episode 100.000000. Reward 18.333333. action 1.000000. mean reward 20.880243.
# World Perf: Episode 103.000000. Reward 14.666667. action 1.000000. mean reward 20.818108.
# World Perf: Episode 106.000000. Reward 24.000000. action 0.000000. mean reward 20.736410.
# World Perf: Episode 109.000000. Reward 30.666667. action 1.000000. mean reward 20.744873.
# World Perf: Episode 112.000000. Reward 23.333333. action 1.000000. mean reward 20.707577.
# World Perf: Episode 115.000000. Reward 27.333333. action 1.000000. mean reward 20.871185.
# World Perf: Episode 118.000000. Reward 13.000000. action 1.000000. mean reward 20.757061.
# World Perf: Episode 121.000000. Reward 19.666667. action 1.000000. mean reward 20.629850.
# World Perf: Episode 124.000000. Reward 12.666667. action 1.000000. mean reward 20.470507.
# World Perf: Episode 127.000000. Reward 21.666667. action 1.000000. mean reward 20.332487.
# World Perf: Episode 130.000000. Reward 25.333333. action 0.000000. mean reward 20.237104.
# World Perf: Episode 133.000000. Reward 18.666667. action 1.000000. mean reward 20.186291.
# World Perf: Episode 136.000000. Reward 18.000000. action 0.000000. mean reward 20.337736.
# World Perf: Episode 139.000000. Reward 32.333333. action 0.000000. mean reward 20.394709.
# World Perf: Episode 142.000000. Reward 23.666667. action 1.000000. mean reward 20.352295.
# World Perf: Episode 145.000000. Reward 30.333333. action 0.000000. mean reward 20.631901.
# World Perf: Episode 148.000000. Reward 27.333333. action 0.000000. mean reward 21.116165.
# World Perf: Episode 151.000000. Reward 10.666667. action 0.000000. mean reward 20.864012.
# World Perf: Episode 154.000000. Reward 31.666667. action 0.000000. mean reward 20.895540.
# World Perf: Episode 157.000000. Reward 17.333333. action 0.000000. mean reward 20.729460.
# World Perf: Episode 160.000000. Reward 27.333333. action 1.000000. mean reward 20.637136.
# World Perf: Episode 163.000000. Reward 27.000000. action 0.000000. mean reward 20.530729.
# World Perf: Episode 166.000000. Reward 26.000000. action 0.000000. mean reward 20.610044.
# World Perf: Episode 169.000000. Reward 29.000000. action 0.000000. mean reward 21.077303.
# World Perf: Episode 172.000000. Reward 20.000000. action 0.000000. mean reward 21.007036.
# World Perf: Episode 175.000000. Reward 18.333333. action 0.000000. mean reward 20.858988.
# World Perf: Episode 178.000000. Reward 24.666667. action 1.000000. mean reward 20.818680.
# World Perf: Episode 181.000000. Reward 18.666667. action 0.000000. mean reward 20.625505.
# World Perf: Episode 184.000000. Reward 26.666667. action 0.000000. mean reward 21.495422.
# World Perf: Episode 187.000000. Reward 25.666667. action 0.000000. mean reward 21.808634.
# World Perf: Episode 190.000000. Reward 22.000000. action 1.000000. mean reward 24.732046.
# World Perf: Episode 193.000000. Reward 23.000000. action 1.000000. mean reward 27.251236.
# World Perf: Episode 196.000000. Reward 21.000000. action 1.000000. mean reward 27.105257.
# World Perf: Episode 199.000000. Reward 32.333333. action 0.000000. mean reward 26.939207.
# World Perf: Episode 202.000000. Reward 14.000000. action 0.000000. mean reward 26.727652.
# World Perf: Episode 205.000000. Reward 20.666667. action 0.000000. mean reward 26.544527.
# World Perf: Episode 208.000000. Reward 13.333333. action 0.000000. mean reward 26.288504.
# World Perf: Episode 211.000000. Reward 16.666667. action 1.000000. mean reward 26.045090.
# World Perf: Episode 214.000000. Reward 25.000000. action 1.000000. mean reward 26.142380.
# World Perf: Episode 217.000000. Reward 19.333333. action 0.000000. mean reward 25.967585.
# World Perf: Episode 220.000000. Reward 14.333333. action 1.000000. mean reward 25.772413.
# World Perf: Episode 223.000000. Reward 14.333333. action 0.000000. mean reward 25.758829.
# World Perf: Episode 226.000000. Reward 17.000000. action 0.000000. mean reward 25.531309.
# World Perf: Episode 229.000000. Reward 39.666667. action 0.000000. mean reward 25.834900.
# World Perf: Episode 232.000000. Reward 21.000000. action 1.000000. mean reward 25.661936.
# World Perf: Episode 235.000000. Reward 30.666667. action 0.000000. mean reward 25.774412.
# World Perf: Episode 238.000000. Reward 48.000000. action 0.000000. mean reward 25.906397.
# World Perf: Episode 241.000000. Reward 21.000000. action 1.000000. mean reward 25.706244.
# World Perf: Episode 244.000000. Reward 17.000000. action 1.000000. mean reward 25.717033.
# World Perf: Episode 247.000000. Reward 27.666667. action 1.000000. mean reward 25.635027.
# World Perf: Episode 250.000000. Reward 21.666667. action 1.000000. mean reward 25.624062.
# World Perf: Episode 253.000000. Reward 27.666667. action 0.000000. mean reward 25.507250.
# World Perf: Episode 256.000000. Reward 23.000000. action 0.000000. mean reward 25.299376.
# World Perf: Episode 259.000000. Reward 21.666667. action 1.000000. mean reward 25.147003.
# World Perf: Episode 262.000000. Reward 36.333333. action 1.000000. mean reward 25.116770.
# World Perf: Episode 265.000000. Reward 12.333333. action 1.000000. mean reward 24.814072.
# World Perf: Episode 268.000000. Reward 14.333333. action 1.000000. mean reward 24.559412.
# World Perf: Episode 271.000000. Reward 14.666667. action 0.000000. mean reward 24.871534.
# World Perf: Episode 274.000000. Reward 29.000000. action 1.000000. mean reward 24.794991.
# World Perf: Episode 277.000000. Reward 17.000000. action 1.000000. mean reward 25.350657.
# World Perf: Episode 280.000000. Reward 22.666667. action 1.000000. mean reward 25.170984.
# World Perf: Episode 283.000000. Reward 29.333333. action 0.000000. mean reward 25.059011.
# World Perf: Episode 286.000000. Reward 24.666667. action 1.000000. mean reward 24.948709.
# World Perf: Episode 289.000000. Reward 13.666667. action 1.000000. mean reward 24.702614.
# World Perf: Episode 292.000000. Reward 17.000000. action 0.000000. mean reward 24.604385.
# World Perf: Episode 295.000000. Reward 20.333333. action 0.000000. mean reward 24.409613.
# World Perf: Episode 298.000000. Reward 37.000000. action 1.000000. mean reward 24.511774.
# World Perf: Episode 301.000000. Reward 16.000000. action 0.000000. mean reward 24.739769.
# World Perf: Episode 304.000000. Reward 26.333333. action 0.000000. mean reward 24.652517.
# World Perf: Episode 307.000000. Reward 14.000000. action 0.000000. mean reward 24.366297.
# World Perf: Episode 310.000000. Reward 18.666667. action 1.000000. mean reward 24.134148.
# World Perf: Episode 313.000000. Reward 23.666667. action 0.000000. mean reward 23.958311.
# World Perf: Episode 316.000000. Reward 19.000000. action 1.000000. mean reward 23.741823.
# World Perf: Episode 319.000000. Reward 20.000000. action 0.000000. mean reward 24.519957.
# World Perf: Episode 322.000000. Reward 19.666667. action 1.000000. mean reward 24.803299.
# World Perf: Episode 325.000000. Reward 19.000000. action 1.000000. mean reward 26.476976.
# World Perf: Episode 328.000000. Reward 15.000000. action 0.000000. mean reward 30.660097.
# World Perf: Episode 331.000000. Reward 20.000000. action 1.000000. mean reward 31.439764.
# World Perf: Episode 334.000000. Reward 27.333333. action 1.000000. mean reward 31.407412.
# World Perf: Episode 337.000000. Reward 22.000000. action 0.000000. mean reward 31.092772.
# World Perf: Episode 340.000000. Reward 13.666667. action 0.000000. mean reward 30.859818.
# World Perf: Episode 343.000000. Reward 18.333333. action 1.000000. mean reward 30.808107.
# World Perf: Episode 346.000000. Reward 34.666667. action 1.000000. mean reward 31.703310.
# World Perf: Episode 349.000000. Reward 14.666667. action 0.000000. mean reward 32.343304.
# World Perf: Episode 352.000000. Reward 22.333333. action 0.000000. mean reward 32.146542.
# World Perf: Episode 355.000000. Reward 20.000000. action 0.000000. mean reward 31.979813.
# World Perf: Episode 358.000000. Reward 30.000000. action 0.000000. mean reward 31.884569.
# World Perf: Episode 361.000000. Reward 25.000000. action 0.000000. mean reward 34.360004.
# World Perf: Episode 364.000000. Reward 26.666667. action 1.000000. mean reward 35.668736.
# World Perf: Episode 367.000000. Reward 18.333333. action 0.000000. mean reward 35.506901.
# World Perf: Episode 370.000000. Reward 29.000000. action 0.000000. mean reward 35.505772.
# World Perf: Episode 373.000000. Reward 19.333333. action 0.000000. mean reward 35.149788.
# World Perf: Episode 376.000000. Reward 41.333333. action 0.000000. mean reward 35.119541.
# World Perf: Episode 379.000000. Reward 13.000000. action 1.000000. mean reward 34.690224.
# World Perf: Episode 382.000000. Reward 37.000000. action 1.000000. mean reward 34.717564.
# World Perf: Episode 385.000000. Reward 20.000000. action 1.000000. mean reward 34.415268.
# World Perf: Episode 388.000000. Reward 18.333333. action 1.000000. mean reward 33.951302.
# World Perf: Episode 391.000000. Reward 22.000000. action 0.000000. mean reward 33.720837.
# World Perf: Episode 394.000000. Reward 15.666667. action 0.000000. mean reward 33.291286.
# World Perf: Episode 397.000000. Reward 30.666667. action 0.000000. mean reward 33.041096.
# World Perf: Episode 400.000000. Reward 58.000000. action 1.000000. mean reward 34.253021.
# World Perf: Episode 403.000000. Reward 18.333333. action 1.000000. mean reward 33.932041.
# World Perf: Episode 406.000000. Reward 31.333333. action 1.000000. mean reward 33.726978.
# World Perf: Episode 409.000000. Reward 16.666667. action 0.000000. mean reward 34.924675.
# World Perf: Episode 412.000000. Reward 18.000000. action 0.000000. mean reward 34.460381.
# World Perf: Episode 415.000000. Reward 19.666667. action 1.000000. mean reward 34.031933.
# World Perf: Episode 418.000000. Reward 16.333333. action 0.000000. mean reward 36.972202.
# World Perf: Episode 421.000000. Reward 21.333333. action 0.000000. mean reward 36.709339.
# World Perf: Episode 424.000000. Reward 20.000000. action 0.000000. mean reward 36.353512.
# World Perf: Episode 427.000000. Reward 33.666667. action 1.000000. mean reward 36.080364.
# World Perf: Episode 430.000000. Reward 19.666667. action 0.000000. mean reward 35.665493.
# World Perf: Episode 433.000000. Reward 22.333333. action 0.000000. mean reward 35.315945.
# World Perf: Episode 436.000000. Reward 17.333333. action 0.000000. mean reward 34.903881.
# World Perf: Episode 439.000000. Reward 27.333333. action 0.000000. mean reward 35.698292.
# World Perf: Episode 442.000000. Reward 26.666667. action 1.000000. mean reward 36.134472.
# World Perf: Episode 445.000000. Reward 16.000000. action 0.000000. mean reward 35.716778.
# World Perf: Episode 448.000000. Reward 14.000000. action 1.000000. mean reward 35.244213.
# World Perf: Episode 451.000000. Reward 54.333333. action 0.000000. mean reward 35.195305.
# World Perf: Episode 454.000000. Reward 15.666667. action 0.000000. mean reward 37.615402.
# World Perf: Episode 457.000000. Reward 19.333333. action 1.000000. mean reward 40.142040.
# World Perf: Episode 460.000000. Reward 13.333333. action 1.000000. mean reward 39.659153.
# World Perf: Episode 463.000000. Reward 12.666667. action 0.000000. mean reward 39.132267.
# World Perf: Episode 466.000000. Reward 23.666667. action 0.000000. mean reward 38.968582.
# World Perf: Episode 469.000000. Reward 17.000000. action 0.000000. mean reward 38.513126.
# World Perf: Episode 472.000000. Reward 17.666667. action 0.000000. mean reward 38.828770.
# World Perf: Episode 475.000000. Reward 17.000000. action 0.000000. mean reward 39.022449.
# World Perf: Episode 478.000000. Reward 21.666667. action 0.000000. mean reward 39.021023.
# World Perf: Episode 481.000000. Reward 13.666667. action 0.000000. mean reward 38.451141.
# World Perf: Episode 484.000000. Reward 30.333333. action 0.000000. mean reward 38.078255.
# World Perf: Episode 487.000000. Reward 27.000000. action 1.000000. mean reward 37.985973.
# World Perf: Episode 490.000000. Reward 21.333333. action 1.000000. mean reward 38.001972.
# World Perf: Episode 493.000000. Reward 16.000000. action 1.000000. mean reward 37.548801.
# World Perf: Episode 496.000000. Reward 18.000000. action 0.000000. mean reward 37.046028.
# World Perf: Episode 499.000000. Reward 17.666667. action 0.000000. mean reward 36.604950.
# World Perf: Episode 502.000000. Reward 18.666667. action 1.000000. mean reward 39.215031.
# World Perf: Episode 505.000000. Reward 18.333333. action 0.000000. mean reward 41.557819.
# World Perf: Episode 508.000000. Reward 21.666667. action 1.000000. mean reward 41.064930.
# World Perf: Episode 511.000000. Reward 24.666667. action 1.000000. mean reward 40.588478.
# World Perf: Episode 514.000000. Reward 23.333333. action 0.000000. mean reward 40.063705.
# World Perf: Episode 517.000000. Reward 29.666667. action 1.000000. mean reward 39.619648.
# World Perf: Episode 520.000000. Reward 14.333333. action 0.000000. mean reward 39.024635.
# World Perf: Episode 523.000000. Reward 22.000000. action 0.000000. mean reward 38.607712.
# World Perf: Episode 526.000000. Reward 13.333333. action 1.000000. mean reward 38.064320.
# World Perf: Episode 529.000000. Reward 16.000000. action 1.000000. mean reward 37.563503.
# World Perf: Episode 532.000000. Reward 32.333333. action 1.000000. mean reward 37.394276.
# World Perf: Episode 535.000000. Reward 12.333333. action 0.000000. mean reward 36.933048.
# World Perf: Episode 538.000000. Reward 25.333333. action 1.000000. mean reward 36.531506.
# World Perf: Episode 541.000000. Reward 13.333333. action 1.000000. mean reward 36.298420.
# World Perf: Episode 544.000000. Reward 13.333333. action 1.000000. mean reward 35.906723.
# World Perf: Episode 547.000000. Reward 14.000000. action 1.000000. mean reward 35.444721.
# World Perf: Episode 550.000000. Reward 16.666667. action 0.000000. mean reward 34.998783.
# World Perf: Episode 553.000000. Reward 21.000000. action 0.000000. mean reward 34.651196.
# World Perf: Episode 556.000000. Reward 24.333333. action 0.000000. mean reward 34.284885.
# World Perf: Episode 559.000000. Reward 19.333333. action 1.000000. mean reward 34.055370.
# World Perf: Episode 562.000000. Reward 13.000000. action 0.000000. mean reward 36.560833.
# World Perf: Episode 565.000000. Reward 30.333333. action 0.000000. mean reward 39.039845.
# World Perf: Episode 568.000000. Reward 14.333333. action 1.000000. mean reward 38.494415.
# World Perf: Episode 571.000000. Reward 27.666667. action 1.000000. mean reward 38.085220.
# World Perf: Episode 574.000000. Reward 14.333333. action 1.000000. mean reward 37.515320.
# World Perf: Episode 577.000000. Reward 13.666667. action 0.000000. mean reward 37.021221.
# World Perf: Episode 580.000000. Reward 14.666667. action 1.000000. mean reward 36.599194.
# World Perf: Episode 583.000000. Reward 16.000000. action 0.000000. mean reward 36.474545.
# World Perf: Episode 586.000000. Reward 30.000000. action 1.000000. mean reward 36.265682.
# World Perf: Episode 589.000000. Reward 22.000000. action 1.000000. mean reward 35.873997.
# World Perf: Episode 592.000000. Reward 29.333333. action 0.000000. mean reward 35.948647.
# World Perf: Episode 595.000000. Reward 25.666667. action 0.000000. mean reward 35.724957.
# World Perf: Episode 598.000000. Reward 18.000000. action 0.000000. mean reward 35.411045.
# World Perf: Episode 601.000000. Reward 19.666667. action 1.000000. mean reward 35.259182.
# World Perf: Episode 604.000000. Reward 26.000000. action 1.000000. mean reward 34.986027.
# World Perf: Episode 607.000000. Reward 19.333333. action 0.000000. mean reward 34.616081.
# World Perf: Episode 610.000000. Reward 14.000000. action 0.000000. mean reward 34.174160.
# World Perf: Episode 613.000000. Reward 31.000000. action 0.000000. mean reward 33.924469.
# World Perf: Episode 616.000000. Reward 23.000000. action 0.000000. mean reward 33.584949.
# World Perf: Episode 619.000000. Reward 20.000000. action 1.000000. mean reward 33.940266.
# World Perf: Episode 622.000000. Reward 20.000000. action 0.000000. mean reward 35.623806.
# World Perf: Episode 625.000000. Reward 43.333333. action 1.000000. mean reward 35.502403.
# World Perf: Episode 628.000000. Reward 19.666667. action 1.000000. mean reward 35.138691.
# World Perf: Episode 631.000000. Reward 25.000000. action 0.000000. mean reward 34.782574.
# World Perf: Episode 634.000000. Reward 29.333333. action 0.000000. mean reward 34.565453.
# World Perf: Episode 637.000000. Reward 19.333333. action 1.000000. mean reward 34.168903.
# World Perf: Episode 640.000000. Reward 34.666667. action 0.000000. mean reward 33.956612.
# World Perf: Episode 643.000000. Reward 18.666667. action 0.000000. mean reward 33.886349.
# World Perf: Episode 646.000000. Reward 29.333333. action 1.000000. mean reward 33.828281.
# World Perf: Episode 649.000000. Reward 33.333333. action 1.000000. mean reward 33.639767.
# World Perf: Episode 652.000000. Reward 26.000000. action 1.000000. mean reward 33.421848.
# World Perf: Episode 655.000000. Reward 22.333333. action 1.000000. mean reward 33.236275.
# World Perf: Episode 658.000000. Reward 14.000000. action 1.000000. mean reward 33.078274.
# World Perf: Episode 661.000000. Reward 16.333333. action 1.000000. mean reward 32.784191.
# World Perf: Episode 664.000000. Reward 35.333333. action 1.000000. mean reward 32.581478.
# World Perf: Episode 667.000000. Reward 24.666667. action 1.000000. mean reward 32.271049.
# World Perf: Episode 670.000000. Reward 15.666667. action 0.000000. mean reward 31.878653.
# World Perf: Episode 673.000000. Reward 21.000000. action 0.000000. mean reward 31.597382.
# World Perf: Episode 676.000000. Reward 14.333333. action 1.000000. mean reward 32.662117.
# World Perf: Episode 679.000000. Reward 14.333333. action 0.000000. mean reward 33.035362.
# World Perf: Episode 682.000000. Reward 23.666667. action 1.000000. mean reward 32.733166.
# World Perf: Episode 685.000000. Reward 32.666667. action 0.000000. mean reward 32.805859.
# World Perf: Episode 688.000000. Reward 30.333333. action 0.000000. mean reward 32.756481.
# World Perf: Episode 691.000000. Reward 20.000000. action 1.000000. mean reward 32.362480.
# World Perf: Episode 694.000000. Reward 27.333333. action 0.000000. mean reward 32.142277.
# World Perf: Episode 697.000000. Reward 21.000000. action 1.000000. mean reward 31.796776.
# World Perf: Episode 700.000000. Reward 17.000000. action 0.000000. mean reward 33.338360.
# World Perf: Episode 703.000000. Reward 20.000000. action 0.000000. mean reward 33.100365.
# World Perf: Episode 706.000000. Reward 27.666667. action 0.000000. mean reward 32.796021.
# World Perf: Episode 709.000000. Reward 36.666667. action 0.000000. mean reward 32.659107.
# World Perf: Episode 712.000000. Reward 14.333333. action 1.000000. mean reward 32.279701.
# World Perf: Episode 715.000000. Reward 26.666667. action 0.000000. mean reward 32.107536.
# World Perf: Episode 718.000000. Reward 38.000000. action 1.000000. mean reward 31.960556.
# World Perf: Episode 721.000000. Reward 39.000000. action 1.000000. mean reward 32.089066.
# World Perf: Episode 724.000000. Reward 19.000000. action 1.000000. mean reward 32.130974.
# World Perf: Episode 727.000000. Reward 15.000000. action 1.000000. mean reward 31.787931.
# World Perf: Episode 730.000000. Reward 17.666667. action 1.000000. mean reward 31.574440.
# World Perf: Episode 733.000000. Reward 20.333333. action 1.000000. mean reward 31.266502.
# World Perf: Episode 736.000000. Reward 13.000000. action 0.000000. mean reward 30.911346.
# World Perf: Episode 739.000000. Reward 24.666667. action 1.000000. mean reward 30.763985.
# World Perf: Episode 742.000000. Reward 33.000000. action 0.000000. mean reward 30.860077.
# World Perf: Episode 745.000000. Reward 18.000000. action 0.000000. mean reward 30.539270.
# World Perf: Episode 748.000000. Reward 27.333333. action 1.000000. mean reward 30.838333.
# World Perf: Episode 751.000000. Reward 15.333333. action 0.000000. mean reward 30.555433.
# World Perf: Episode 754.000000. Reward 22.666667. action 0.000000. mean reward 30.598089.
# World Perf: Episode 757.000000. Reward 18.000000. action 0.000000. mean reward 31.443541.
# World Perf: Episode 760.000000. Reward 28.333333. action 0.000000. mean reward 31.303864.
# World Perf: Episode 763.000000. Reward 23.000000. action 0.000000. mean reward 31.166504.
# World Perf: Episode 766.000000. Reward 26.000000. action 0.000000. mean reward 30.954046.
# World Perf: Episode 769.000000. Reward 23.666667. action 0.000000. mean reward 30.818102.
# World Perf: Episode 772.000000. Reward 28.000000. action 1.000000. mean reward 30.784506.
# World Perf: Episode 775.000000. Reward 18.000000. action 1.000000. mean reward 30.475853.
# World Perf: Episode 778.000000. Reward 25.000000. action 1.000000. mean reward 30.340128.
# World Perf: Episode 781.000000. Reward 13.000000. action 1.000000. mean reward 30.090475.
# World Perf: Episode 784.000000. Reward 20.666667. action 1.000000. mean reward 29.891687.
# World Perf: Episode 787.000000. Reward 15.666667. action 1.000000. mean reward 29.665808.
# World Perf: Episode 790.000000. Reward 18.000000. action 0.000000. mean reward 29.490797.
# World Perf: Episode 793.000000. Reward 15.666667. action 1.000000. mean reward 29.194344.
# World Perf: Episode 796.000000. Reward 22.000000. action 0.000000. mean reward 28.924959.
# World Perf: Episode 799.000000. Reward 24.000000. action 0.000000. mean reward 28.705751.
# World Perf: Episode 802.000000. Reward 21.000000. action 1.000000. mean reward 28.448250.
# World Perf: Episode 805.000000. Reward 20.666667. action 1.000000. mean reward 28.272514.
# World Perf: Episode 808.000000. Reward 29.000000. action 0.000000. mean reward 28.111834.
# World Perf: Episode 811.000000. Reward 24.000000. action 1.000000. mean reward 27.895136.
# World Perf: Episode 814.000000. Reward 20.333333. action 0.000000. mean reward 27.679525.
# World Perf: Episode 817.000000. Reward 17.000000. action 1.000000. mean reward 27.427259.
# World Perf: Episode 820.000000. Reward 15.333333. action 0.000000. mean reward 27.341942.
# World Perf: Episode 823.000000. Reward 17.000000. action 0.000000. mean reward 27.124138.
# World Perf: Episode 826.000000. Reward 19.666667. action 1.000000. mean reward 27.427719.
# World Perf: Episode 829.000000. Reward 36.000000. action 1.000000. mean reward 27.330965.
# World Perf: Episode 832.000000. Reward 27.000000. action 0.000000. mean reward 27.309752.
# World Perf: Episode 835.000000. Reward 21.000000. action 1.000000. mean reward 27.443441.
# World Perf: Episode 838.000000. Reward 18.666667. action 1.000000. mean reward 27.215569.
# World Perf: Episode 841.000000. Reward 32.000000. action 0.000000. mean reward 27.122278.
# World Perf: Episode 844.000000. Reward 19.666667. action 1.000000. mean reward 26.861830.
# World Perf: Episode 847.000000. Reward 27.333333. action 1.000000. mean reward 26.745920.
# World Perf: Episode 850.000000. Reward 14.000000. action 1.000000. mean reward 26.490095.
# World Perf: Episode 853.000000. Reward 33.666667. action 1.000000. mean reward 26.362869.
# World Perf: Episode 856.000000. Reward 32.000000. action 0.000000. mean reward 26.284185.
# World Perf: Episode 859.000000. Reward 13.666667. action 0.000000. mean reward 26.008108.
# World Perf: Episode 862.000000. Reward 19.333333. action 0.000000. mean reward 25.746595.
# World Perf: Episode 865.000000. Reward 15.000000. action 0.000000. mean reward 26.971769.
# World Perf: Episode 868.000000. Reward 12.666667. action 1.000000. mean reward 27.111052.
# World Perf: Episode 871.000000. Reward 28.666667. action 0.000000. mean reward 26.927345.
# World Perf: Episode 874.000000. Reward 51.000000. action 0.000000. mean reward 27.071661.
# World Perf: Episode 877.000000. Reward 22.000000. action 1.000000. mean reward 27.332083.
# World Perf: Episode 880.000000. Reward 17.666667. action 0.000000. mean reward 27.054003.
# World Perf: Episode 883.000000. Reward 23.000000. action 1.000000. mean reward 26.872932.
# World Perf: Episode 886.000000. Reward 37.333333. action 0.000000. mean reward 26.804632.
# World Perf: Episode 889.000000. Reward 12.000000. action 1.000000. mean reward 26.485048.
# World Perf: Episode 892.000000. Reward 21.666667. action 1.000000. mean reward 26.279524.
# World Perf: Episode 895.000000. Reward 47.333333. action 1.000000. mean reward 26.356928.
# World Perf: Episode 898.000000. Reward 12.000000. action 1.000000. mean reward 26.116877.
# World Perf: Episode 901.000000. Reward 34.000000. action 0.000000. mean reward 26.115683.
# World Perf: Episode 904.000000. Reward 18.000000. action 1.000000. mean reward 25.847696.
# World Perf: Episode 907.000000. Reward 26.333333. action 0.000000. mean reward 25.684814.
# World Perf: Episode 910.000000. Reward 14.333333. action 1.000000. mean reward 25.401413.
# World Perf: Episode 913.000000. Reward 25.666667. action 0.000000. mean reward 25.840508.
# World Perf: Episode 916.000000. Reward 33.000000. action 0.000000. mean reward 25.827280.
# World Perf: Episode 919.000000. Reward 28.666667. action 1.000000. mean reward 25.917648.
# World Perf: Episode 922.000000. Reward 12.666667. action 1.000000. mean reward 25.647642.
# World Perf: Episode 925.000000. Reward 26.000000. action 1.000000. mean reward 25.502844.
# World Perf: Episode 928.000000. Reward 32.333333. action 1.000000. mean reward 25.465525.
# World Perf: Episode 931.000000. Reward 21.666667. action 0.000000. mean reward 25.337915.
# World Perf: Episode 934.000000. Reward 29.000000. action 0.000000. mean reward 25.376364.
# World Perf: Episode 937.000000. Reward 21.333333. action 1.000000. mean reward 25.717852.
# World Perf: Episode 940.000000. Reward 28.000000. action 1.000000. mean reward 25.986788.
# World Perf: Episode 943.000000. Reward 21.333333. action 0.000000. mean reward 27.844534.
# World Perf: Episode 946.000000. Reward 40.000000. action 0.000000. mean reward 27.985426.
# World Perf: Episode 949.000000. Reward 24.000000. action 1.000000. mean reward 27.995195.
# World Perf: Episode 952.000000. Reward 21.333333. action 1.000000. mean reward 27.701307.
# World Perf: Episode 955.000000. Reward 16.333333. action 0.000000. mean reward 27.409630.
# World Perf: Episode 958.000000. Reward 20.333333. action 0.000000. mean reward 27.234724.
# World Perf: Episode 961.000000. Reward 30.666667. action 0.000000. mean reward 29.105558.
# World Perf: Episode 964.000000. Reward 19.000000. action 1.000000. mean reward 29.252851.
# World Perf: Episode 967.000000. Reward 15.666667. action 1.000000. mean reward 28.999971.
# World Perf: Episode 970.000000. Reward 28.333333. action 0.000000. mean reward 28.807371.
# World Perf: Episode 973.000000. Reward 18.000000. action 0.000000. mean reward 28.501108.
# World Perf: Episode 976.000000. Reward 12.000000. action 1.000000. mean reward 28.140650.
# World Perf: Episode 979.000000. Reward 27.666667. action 0.000000. mean reward 27.985826.
# World Perf: Episode 982.000000. Reward 13.333333. action 1.000000. mean reward 27.853407.
# World Perf: Episode 985.000000. Reward 28.333333. action 1.000000. mean reward 27.630180.
# World Perf: Episode 988.000000. Reward 16.000000. action 1.000000. mean reward 28.039604.
# World Perf: Episode 991.000000. Reward 15.333333. action 0.000000. mean reward 27.687288.
# World Perf: Episode 994.000000. Reward 32.333333. action 1.000000. mean reward 27.533087.
# World Perf: Episode 997.000000. Reward 20.666667. action 1.000000. mean reward 27.441587.
# World Perf: Episode 1000.000000. Reward 19.666667. action 1.000000. mean reward 27.218241.
# World Perf: Episode 1003.000000. Reward 18.333333. action 0.000000. mean reward 27.076759.
# World Perf: Episode 1006.000000. Reward 17.666667. action 1.000000. mean reward 26.794662.
# World Perf: Episode 1009.000000. Reward 23.333333. action 1.000000. mean reward 26.548607.
# World Perf: Episode 1012.000000. Reward 18.333333. action 0.000000. mean reward 29.193520.
# World Perf: Episode 1015.000000. Reward 31.666667. action 1.000000. mean reward 29.113882.
# World Perf: Episode 1018.000000. Reward 16.000000. action 1.000000. mean reward 32.009407.
# World Perf: Episode 1021.000000. Reward 20.000000. action 1.000000. mean reward 31.621635.
# World Perf: Episode 1024.000000. Reward 20.666667. action 0.000000. mean reward 31.276871.
# World Perf: Episode 1027.000000. Reward 19.000000. action 0.000000. mean reward 30.948685.
# World Perf: Episode 1030.000000. Reward 19.000000. action 1.000000. mean reward 32.642834.
# World Perf: Episode 1033.000000. Reward 22.000000. action 0.000000. mean reward 35.158916.
# World Perf: Episode 1036.000000. Reward 25.333333. action 0.000000. mean reward 34.883308.
# World Perf: Episode 1039.000000. Reward 44.000000. action 0.000000. mean reward 37.522217.
# World Perf: Episode 1042.000000. Reward 25.333333. action 1.000000. mean reward 37.150299.
# World Perf: Episode 1045.000000. Reward 28.000000. action 0.000000. mean reward 37.285305.
# World Perf: Episode 1048.000000. Reward 22.333333. action 0.000000. mean reward 36.843353.
# World Perf: Episode 1051.000000. Reward 38.666667. action 1.000000. mean reward 36.616581.
# World Perf: Episode 1054.000000. Reward 20.000000. action 0.000000. mean reward 36.320160.
# World Perf: Episode 1057.000000. Reward 48.333333. action 0.000000. mean reward 36.151531.
# World Perf: Episode 1060.000000. Reward 23.666667. action 0.000000. mean reward 35.766136.
# World Perf: Episode 1063.000000. Reward 27.000000. action 0.000000. mean reward 35.396801.
# World Perf: Episode 1066.000000. Reward 14.000000. action 0.000000. mean reward 35.237434.
# World Perf: Episode 1069.000000. Reward 17.666667. action 1.000000. mean reward 35.007801.
# World Perf: Episode 1072.000000. Reward 19.333333. action 0.000000. mean reward 34.627510.
# World Perf: Episode 1075.000000. Reward 38.000000. action 1.000000. mean reward 34.419945.
# World Perf: Episode 1078.000000. Reward 20.666667. action 0.000000. mean reward 34.039726.
# World Perf: Episode 1081.000000. Reward 16.000000. action 0.000000. mean reward 33.617123.
# World Perf: Episode 1084.000000. Reward 24.333333. action 0.000000. mean reward 33.559868.
# World Perf: Episode 1087.000000. Reward 21.000000. action 1.000000. mean reward 33.277729.
# World Perf: Episode 1090.000000. Reward 13.666667. action 0.000000. mean reward 34.003868.
# World Perf: Episode 1093.000000. Reward 32.666667. action 1.000000. mean reward 33.717594.
# World Perf: Episode 1096.000000. Reward 30.333333. action 1.000000. mean reward 33.747200.
# World Perf: Episode 1099.000000. Reward 18.666667. action 0.000000. mean reward 33.625797.
# World Perf: Episode 1102.000000. Reward 22.666667. action 0.000000. mean reward 33.564724.
# World Perf: Episode 1105.000000. Reward 15.000000. action 1.000000. mean reward 33.223885.
# World Perf: Episode 1108.000000. Reward 18.333333. action 1.000000. mean reward 33.403622.
# World Perf: Episode 1111.000000. Reward 21.333333. action 1.000000. mean reward 33.438175.
# World Perf: Episode 1114.000000. Reward 18.333333. action 1.000000. mean reward 33.611271.
# World Perf: Episode 1117.000000. Reward 20.666667. action 0.000000. mean reward 33.219845.
# World Perf: Episode 1120.000000. Reward 28.666667. action 0.000000. mean reward 33.005207.
# World Perf: Episode 1123.000000. Reward 16.000000. action 1.000000. mean reward 32.725849.
# World Perf: Episode 1126.000000. Reward 21.666667. action 1.000000. mean reward 32.460846.
# World Perf: Episode 1129.000000. Reward 18.000000. action 0.000000. mean reward 32.154789.
# World Perf: Episode 1132.000000. Reward 28.666667. action 0.000000. mean reward 31.924726.
# World Perf: Episode 1135.000000. Reward 49.000000. action 1.000000. mean reward 31.879950.
# World Perf: Episode 1138.000000. Reward 23.333333. action 1.000000. mean reward 31.672838.
# World Perf: Episode 1141.000000. Reward 24.333333. action 1.000000. mean reward 31.380806.
# World Perf: Episode 1144.000000. Reward 18.333333. action 1.000000. mean reward 31.032249.
# World Perf: Episode 1147.000000. Reward 26.333333. action 1.000000. mean reward 30.736786.
# World Perf: Episode 1150.000000. Reward 11.000000. action 0.000000. mean reward 30.320923.
# World Perf: Episode 1153.000000. Reward 30.333333. action 1.000000. mean reward 30.135725.
# World Perf: Episode 1156.000000. Reward 28.666667. action 0.000000. mean reward 29.914215.
# World Perf: Episode 1159.000000. Reward 17.666667. action 1.000000. mean reward 29.686193.
# World Perf: Episode 1162.000000. Reward 25.333333. action 0.000000. mean reward 31.422529.
# World Perf: Episode 1165.000000. Reward 17.666667. action 0.000000. mean reward 31.064135.
# World Perf: Episode 1168.000000. Reward 30.333333. action 0.000000. mean reward 30.823616.
# World Perf: Episode 1171.000000. Reward 19.333333. action 0.000000. mean reward 30.544664.
# World Perf: Episode 1174.000000. Reward 20.000000. action 0.000000. mean reward 30.719429.
# World Perf: Episode 1177.000000. Reward 30.666667. action 0.000000. mean reward 30.560724.
# World Perf: Episode 1180.000000. Reward 21.666667. action 0.000000. mean reward 31.162605.
# World Perf: Episode 1183.000000. Reward 25.333333. action 1.000000. mean reward 30.948885.
# World Perf: Episode 1186.000000. Reward 25.000000. action 1.000000. mean reward 30.709097.
# World Perf: Episode 1189.000000. Reward 21.000000. action 0.000000. mean reward 30.656042.
# World Perf: Episode 1192.000000. Reward 19.666667. action 0.000000. mean reward 30.471634.
# World Perf: Episode 1195.000000. Reward 49.666667. action 0.000000. mean reward 30.508120.
# World Perf: Episode 1198.000000. Reward 20.000000. action 1.000000. mean reward 30.215960.
# World Perf: Episode 1201.000000. Reward 22.333333. action 1.000000. mean reward 29.992836.
# World Perf: Episode 1204.000000. Reward 18.333333. action 0.000000. mean reward 29.759699.
# World Perf: Episode 1207.000000. Reward 15.666667. action 0.000000. mean reward 30.717279.
# World Perf: Episode 1210.000000. Reward 18.333333. action 1.000000. mean reward 30.393888.
# World Perf: Episode 1213.000000. Reward 20.333333. action 0.000000. mean reward 30.180082.
# World Perf: Episode 1216.000000. Reward 20.666667. action 1.000000. mean reward 29.943933.
# World Perf: Episode 1219.000000. Reward 19.333333. action 1.000000. mean reward 29.646072.
# World Perf: Episode 1222.000000. Reward 13.333333. action 0.000000. mean reward 29.292074.
# World Perf: Episode 1225.000000. Reward 16.000000. action 0.000000. mean reward 28.977156.
# World Perf: Episode 1228.000000. Reward 16.666667. action 1.000000. mean reward 29.090155.
# World Perf: Episode 1231.000000. Reward 18.000000. action 0.000000. mean reward 28.822975.
# World Perf: Episode 1234.000000. Reward 22.666667. action 0.000000. mean reward 30.531244.
# World Perf: Episode 1237.000000. Reward 25.000000. action 1.000000. mean reward 30.742914.
# World Perf: Episode 1240.000000. Reward 18.000000. action 1.000000. mean reward 30.538712.
# World Perf: Episode 1243.000000. Reward 14.000000. action 1.000000. mean reward 30.224367.
# World Perf: Episode 1246.000000. Reward 37.000000. action 1.000000. mean reward 30.087179.
# World Perf: Episode 1249.000000. Reward 22.000000. action 0.000000. mean reward 29.778025.
# World Perf: Episode 1252.000000. Reward 22.666667. action 0.000000. mean reward 29.535446.
# World Perf: Episode 1255.000000. Reward 29.666667. action 1.000000. mean reward 29.610558.
# World Perf: Episode 1258.000000. Reward 33.000000. action 1.000000. mean reward 29.975687.
# World Perf: Episode 1261.000000. Reward 21.666667. action 1.000000. mean reward 30.082586.
# World Perf: Episode 1264.000000. Reward 32.666667. action 0.000000. mean reward 29.961878.
# World Perf: Episode 1267.000000. Reward 19.333333. action 1.000000. mean reward 29.659231.
# World Perf: Episode 1270.000000. Reward 13.666667. action 0.000000. mean reward 29.751167.
# World Perf: Episode 1273.000000. Reward 20.000000. action 0.000000. mean reward 29.407774.
# World Perf: Episode 1276.000000. Reward 17.000000. action 0.000000. mean reward 29.135368.
# World Perf: Episode 1279.000000. Reward 25.666667. action 1.000000. mean reward 28.889368.
# World Perf: Episode 1282.000000. Reward 23.333333. action 1.000000. mean reward 28.689209.
# World Perf: Episode 1285.000000. Reward 29.333333. action 0.000000. mean reward 28.649946.
# World Perf: Episode 1288.000000. Reward 28.333333. action 0.000000. mean reward 28.446411.
# World Perf: Episode 1291.000000. Reward 22.000000. action 0.000000. mean reward 28.627663.
# World Perf: Episode 1294.000000. Reward 17.000000. action 1.000000. mean reward 28.336668.
# World Perf: Episode 1297.000000. Reward 12.666667. action 0.000000. mean reward 28.037674.
# World Perf: Episode 1300.000000. Reward 31.333333. action 0.000000. mean reward 27.874609.
# World Perf: Episode 1303.000000. Reward 10.333333. action 0.000000. mean reward 27.631186.
# World Perf: Episode 1306.000000. Reward 27.000000. action 1.000000. mean reward 27.484810.
# World Perf: Episode 1309.000000. Reward 23.333333. action 1.000000. mean reward 27.333427.
# World Perf: Episode 1312.000000. Reward 24.666667. action 1.000000. mean reward 27.127722.
# World Perf: Episode 1315.000000. Reward 15.000000. action 1.000000. mean reward 26.833265.
# World Perf: Episode 1318.000000. Reward 14.000000. action 1.000000. mean reward 26.502167.
# World Perf: Episode 1321.000000. Reward 14.000000. action 0.000000. mean reward 26.205742.
# World Perf: Episode 1324.000000. Reward 15.666667. action 0.000000. mean reward 26.141314.
# World Perf: Episode 1327.000000. Reward 20.000000. action 0.000000. mean reward 26.044172.
# World Perf: Episode 1330.000000. Reward 24.333333. action 1.000000. mean reward 25.894409.
# World Perf: Episode 1333.000000. Reward 20.000000. action 0.000000. mean reward 25.649176.
# World Perf: Episode 1336.000000. Reward 19.333333. action 0.000000. mean reward 25.384825.
# World Perf: Episode 1339.000000. Reward 22.000000. action 1.000000. mean reward 25.613184.
# World Perf: Episode 1342.000000. Reward 17.333333. action 1.000000. mean reward 25.384201.
# World Perf: Episode 1345.000000. Reward 34.666667. action 0.000000. mean reward 25.511497.
# World Perf: Episode 1348.000000. Reward 24.666667. action 1.000000. mean reward 25.347755.
# World Perf: Episode 1351.000000. Reward 12.666667. action 0.000000. mean reward 25.025846.
# World Perf: Episode 1354.000000. Reward 16.666667. action 1.000000. mean reward 24.773363.
# World Perf: Episode 1357.000000. Reward 30.666667. action 1.000000. mean reward 24.696596.
# World Perf: Episode 1360.000000. Reward 19.000000. action 1.000000. mean reward 25.365753.
# World Perf: Episode 1363.000000. Reward 25.000000. action 0.000000. mean reward 25.257210.
# World Perf: Episode 1366.000000. Reward 27.000000. action 1.000000. mean reward 25.128782.
# World Perf: Episode 1369.000000. Reward 18.666667. action 0.000000. mean reward 24.900434.
# World Perf: Episode 1372.000000. Reward 17.666667. action 0.000000. mean reward 24.710527.
# World Perf: Episode 1375.000000. Reward 14.666667. action 1.000000. mean reward 25.152466.
# World Perf: Episode 1378.000000. Reward 31.000000. action 0.000000. mean reward 25.350512.
# World Perf: Episode 1381.000000. Reward 21.333333. action 1.000000. mean reward 26.113844.
# World Perf: Episode 1384.000000. Reward 15.333333. action 1.000000. mean reward 26.899679.
# World Perf: Episode 1387.000000. Reward 17.666667. action 1.000000. mean reward 26.737259.
# World Perf: Episode 1390.000000. Reward 21.666667. action 1.000000. mean reward 26.501350.
# World Perf: Episode 1393.000000. Reward 16.000000. action 0.000000. mean reward 26.239737.
# World Perf: Episode 1396.000000. Reward 21.000000. action 0.000000. mean reward 26.066895.
# World Perf: Episode 1399.000000. Reward 22.333333. action 1.000000. mean reward 25.951075.
# World Perf: Episode 1402.000000. Reward 12.666667. action 1.000000. mean reward 25.884535.
# World Perf: Episode 1405.000000. Reward 21.000000. action 1.000000. mean reward 25.684275.
# World Perf: Episode 1408.000000. Reward 21.666667. action 1.000000. mean reward 25.561884.
# World Perf: Episode 1411.000000. Reward 33.666667. action 0.000000. mean reward 27.506384.
# World Perf: Episode 1414.000000. Reward 24.333333. action 1.000000. mean reward 27.586182.
# World Perf: Episode 1417.000000. Reward 27.333333. action 1.000000. mean reward 27.434164.
# World Perf: Episode 1420.000000. Reward 20.666667. action 0.000000. mean reward 27.171844.
# World Perf: Episode 1423.000000. Reward 29.000000. action 0.000000. mean reward 27.046503.
# World Perf: Episode 1426.000000. Reward 17.000000. action 1.000000. mean reward 26.740677.
# World Perf: Episode 1429.000000. Reward 18.333333. action 0.000000. mean reward 26.656105.
# World Perf: Episode 1432.000000. Reward 16.000000. action 1.000000. mean reward 26.583506.
# World Perf: Episode 1435.000000. Reward 21.666667. action 1.000000. mean reward 29.294870.
# World Perf: Episode 1438.000000. Reward 22.000000. action 0.000000. mean reward 28.978590.
# World Perf: Episode 1441.000000. Reward 22.666667. action 0.000000. mean reward 28.803019.
# World Perf: Episode 1444.000000. Reward 37.333333. action 0.000000. mean reward 28.699224.
# World Perf: Episode 1447.000000. Reward 28.333333. action 0.000000. mean reward 30.396017.
# World Perf: Episode 1450.000000. Reward 23.000000. action 0.000000. mean reward 32.402828.
# World Perf: Episode 1453.000000. Reward 23.666667. action 1.000000. mean reward 32.038490.
# World Perf: Episode 1456.000000. Reward 14.666667. action 0.000000. mean reward 32.111042.
# World Perf: Episode 1459.000000. Reward 22.000000. action 0.000000. mean reward 31.793137.
# World Perf: Episode 1462.000000. Reward 11.666667. action 1.000000. mean reward 31.406158.
# World Perf: Episode 1465.000000. Reward 29.666667. action 0.000000. mean reward 31.174768.
# World Perf: Episode 1468.000000. Reward 25.000000. action 0.000000. mean reward 31.030100.
# World Perf: Episode 1471.000000. Reward 23.000000. action 0.000000. mean reward 31.143373.
# World Perf: Episode 1474.000000. Reward 17.666667. action 1.000000. mean reward 31.624529.
# World Perf: Episode 1477.000000. Reward 18.000000. action 0.000000. mean reward 31.431990.
# World Perf: Episode 1480.000000. Reward 24.000000. action 0.000000. mean reward 31.164358.
# World Perf: Episode 1483.000000. Reward 21.333333. action 0.000000. mean reward 30.822039.
# World Perf: Episode 1486.000000. Reward 15.666667. action 0.000000. mean reward 30.610060.
# World Perf: Episode 1489.000000. Reward 23.333333. action 1.000000. mean reward 30.640787.
# World Perf: Episode 1492.000000. Reward 24.000000. action 1.000000. mean reward 30.377386.
# World Perf: Episode 1495.000000. Reward 16.000000. action 0.000000. mean reward 30.055719.
# World Perf: Episode 1498.000000. Reward 19.000000. action 0.000000. mean reward 29.837751.
# World Perf: Episode 1501.000000. Reward 24.000000. action 1.000000. mean reward 29.700743.
# World Perf: Episode 1504.000000. Reward 26.000000. action 0.000000. mean reward 29.550840.
# World Perf: Episode 1507.000000. Reward 14.666667. action 1.000000. mean reward 29.221130.
# World Perf: Episode 1510.000000. Reward 20.000000. action 1.000000. mean reward 28.939463.
# World Perf: Episode 1513.000000. Reward 32.666667. action 0.000000. mean reward 28.914612.
# World Perf: Episode 1516.000000. Reward 22.000000. action 0.000000. mean reward 28.996162.
# World Perf: Episode 1519.000000. Reward 24.333333. action 1.000000. mean reward 28.742582.
# World Perf: Episode 1522.000000. Reward 21.333333. action 0.000000. mean reward 28.545275.
# World Perf: Episode 1525.000000. Reward 26.333333. action 0.000000. mean reward 28.347784.
# World Perf: Episode 1528.000000. Reward 17.333333. action 1.000000. mean reward 28.311350.
# World Perf: Episode 1531.000000. Reward 20.666667. action 0.000000. mean reward 28.102407.
# World Perf: Episode 1534.000000. Reward 23.333333. action 0.000000. mean reward 28.058985.
# World Perf: Episode 1537.000000. Reward 21.666667. action 0.000000. mean reward 27.889380.
# World Perf: Episode 1540.000000. Reward 16.666667. action 0.000000. mean reward 27.797171.
# World Perf: Episode 1543.000000. Reward 17.333333. action 0.000000. mean reward 27.477304.
# World Perf: Episode 1546.000000. Reward 15.000000. action 1.000000. mean reward 27.169214.
# World Perf: Episode 1549.000000. Reward 15.333333. action 0.000000. mean reward 26.883974.
# World Perf: Episode 1552.000000. Reward 20.000000. action 1.000000. mean reward 26.647888.
# World Perf: Episode 1555.000000. Reward 17.000000. action 1.000000. mean reward 26.414520.
# World Perf: Episode 1558.000000. Reward 13.666667. action 1.000000. mean reward 26.095245.
# World Perf: Episode 1561.000000. Reward 18.333333. action 0.000000. mean reward 25.821981.
# World Perf: Episode 1564.000000. Reward 24.000000. action 0.000000. mean reward 25.636414.
# World Perf: Episode 1567.000000. Reward 19.666667. action 0.000000. mean reward 25.425306.
# World Perf: Episode 1570.000000. Reward 31.333333. action 1.000000. mean reward 25.698662.
# World Perf: Episode 1573.000000. Reward 29.333333. action 1.000000. mean reward 25.614084.
# World Perf: Episode 1576.000000. Reward 23.000000. action 0.000000. mean reward 25.431433.
# World Perf: Episode 1579.000000. Reward 29.666667. action 1.000000. mean reward 25.352644.
# World Perf: Episode 1582.000000. Reward 20.333333. action 0.000000. mean reward 25.112196.
# World Perf: Episode 1585.000000. Reward 30.333333. action 0.000000. mean reward 25.000963.
# World Perf: Episode 1588.000000. Reward 18.666667. action 1.000000. mean reward 24.825508.
# World Perf: Episode 1591.000000. Reward 24.666667. action 0.000000. mean reward 25.441984.
# World Perf: Episode 1594.000000. Reward 35.333333. action 0.000000. mean reward 25.486532.
# ...
# World Perf: Episode 1771.000000. Reward 29.666667. action 0.000000. mean reward 23.163910.
# World Perf: Episode 1774.000000. Reward 14.666667. action 0.000000. mean reward 23.056242.
# World Perf: Episode 1777.000000. Reward 17.000000. action 0.000000. mean reward 22.847185.
# World Perf: Episode 1780.000000. Reward 13.000000. action 0.000000. mean reward 22.707794.
# World Perf: Episode 1783.000000. Reward 14.666667. action 0.000000. mean reward 22.486208.
# World Perf: Episode 1786.000000. Reward 16.666667. action 0.000000. mean reward 22.609026.
# World Perf: Episode 1789.000000. Reward 23.000000. action 1.000000. mean reward 22.679779.
# World Perf: Episode 1792.000000. Reward 30.000000. action 0.000000. mean reward 22.923456.
# World Perf: Episode 1795.000000. Reward 20.000000. action 0.000000. mean reward 25.189217.
# World Perf: Episode 1798.000000. Reward 14.333333. action 0.000000. mean reward 25.363153.
# World Perf: Episode 1801.000000. Reward 37.666667. action 0.000000. mean reward 25.425241.
# World Perf: Episode 1804.000000. Reward 20.333333. action 0.000000. mean reward 25.192591.
# World Perf: Episode 1807.000000. Reward 23.666667. action 1.000000. mean reward 25.008352.
# World Perf: Episode 1810.000000. Reward 15.666667. action 1.000000. mean reward 25.299904.
# World Perf: Episode 1813.000000. Reward 18.000000. action 1.000000. mean reward 25.049185.
# World Perf: Episode 1816.000000. Reward 15.666667. action 1.000000. mean reward 24.855860.
# World Perf: Episode 1819.000000. Reward 25.666667. action 0.000000. mean reward 24.761324.
# World Perf: Episode 1822.000000. Reward 18.333333. action 0.000000. mean reward 26.524248.
# World Perf: Episode 1825.000000. Reward 15.666667. action 0.000000. mean reward 29.162704.
# World Perf: Episode 1828.000000. Reward 16.000000. action 0.000000. mean reward 29.286577.
# World Perf: Episode 1831.000000. Reward 17.333333. action 0.000000. mean reward 28.968872.
# World Perf: Episode 1834.000000. Reward 23.000000. action 1.000000. mean reward 28.822561.
# World Perf: Episode 1837.000000. Reward 21.666667. action 1.000000. mean reward 28.987495.
# World Perf: Episode 1840.000000. Reward 20.000000. action 1.000000. mean reward 28.717798.
# World Perf: Episode 1843.000000. Reward 15.000000. action 1.000000. mean reward 28.739237.
# World Perf: Episode 1846.000000. Reward 21.333333. action 0.000000. mean reward 28.476294.
# World Perf: Episode 1849.000000. Reward 15.333333. action 0.000000. mean reward 28.236128.
# World Perf: Episode 1852.000000. Reward 22.333333. action 0.000000. mean reward 27.939898.
# World Perf: Episode 1855.000000. Reward 13.666667. action 0.000000. mean reward 27.695755.
# World Perf: Episode 1858.000000. Reward 29.666667. action 0.000000. mean reward 27.665453.
# World Perf: Episode 1861.000000. Reward 38.333333. action 0.000000. mean reward 30.356087.
# World Perf: Episode 1864.000000. Reward 15.333333. action 0.000000. mean reward 30.283554.
# World Perf: Episode 1867.000000. Reward 23.333333. action 0.000000. mean reward 30.099394.
# World Perf: Episode 1870.000000. Reward 16.666667. action 0.000000. mean reward 30.314835.
# World Perf: Episode 1873.000000. Reward 25.333333. action 1.000000. mean reward 30.080465.
# World Perf: Episode 1876.000000. Reward 24.666667. action 1.000000. mean reward 29.927803.
# World Perf: Episode 1879.000000. Reward 18.000000. action 0.000000. mean reward 29.610327.
# World Perf: Episode 1882.000000. Reward 19.000000. action 1.000000. mean reward 29.380098.
# World Perf: Episode 1885.000000. Reward 24.333333. action 0.000000. mean reward 29.841974.
# World Perf: Episode 1888.000000. Reward 22.666667. action 0.000000. mean reward 30.170362.
# World Perf: Episode 1891.000000. Reward 19.000000. action 1.000000. mean reward 30.226822.
# World Perf: Episode 1894.000000. Reward 23.000000. action 1.000000. mean reward 30.011635.
# World Perf: Episode 1897.000000. Reward 18.333333. action 0.000000. mean reward 29.868658.
# World Perf: Episode 1900.000000. Reward 35.666667. action 0.000000. mean reward 29.805283.
# World Perf: Episode 1903.000000. Reward 16.333333. action 1.000000. mean reward 29.480284.
# World Perf: Episode 1906.000000. Reward 31.333333. action 0.000000. mean reward 29.285257.
# World Perf: Episode 1909.000000. Reward 22.333333. action 1.000000. mean reward 29.116903.
# World Perf: Episode 1912.000000. Reward 27.333333. action 0.000000. mean reward 28.967918.
# World Perf: Episode 1915.000000. Reward 14.000000. action 0.000000. mean reward 28.733454.
# World Perf: Episode 1918.000000. Reward 32.333333. action 1.000000. mean reward 28.558695.
# World Perf: Episode 1921.000000. Reward 12.666667. action 1.000000. mean reward 28.248688.
# World Perf: Episode 1924.000000. Reward 28.333333. action 0.000000. mean reward 28.285234.
# World Perf: Episode 1927.000000. Reward 30.333333. action 0.000000. mean reward 28.092079.
# World Perf: Episode 1930.000000. Reward 19.666667. action 1.000000. mean reward 27.875540.
# World Perf: Episode 1933.000000. Reward 25.000000. action 1.000000. mean reward 27.805466.
# World Perf: Episode 1936.000000. Reward 32.666667. action 0.000000. mean reward 27.763657.
# World Perf: Episode 1939.000000. Reward 12.000000. action 0.000000. mean reward 27.419821.
# World Perf: Episode 1942.000000. Reward 14.000000. action 0.000000. mean reward 27.336470.
# World Perf: Episode 1945.000000. Reward 23.000000. action 0.000000. mean reward 27.145586.
# World Perf: Episode 1948.000000. Reward 21.000000. action 1.000000. mean reward 26.917532.
# World Perf: Episode 1951.000000. Reward 20.333333. action 1.000000. mean reward 26.785295.
# World Perf: Episode 1954.000000. Reward 24.666667. action 1.000000. mean reward 26.679064.
# World Perf: Episode 1957.000000. Reward 36.000000. action 0.000000. mean reward 26.600637.
# World Perf: Episode 1960.000000. Reward 25.333333. action 1.000000. mean reward 26.403154.
# World Perf: Episode 1963.000000. Reward 23.000000. action 0.000000. mean reward 26.342203.
# World Perf: Episode 1966.000000. Reward 23.000000. action 0.000000. mean reward 26.232216.
# World Perf: Episode 1969.000000. Reward 18.000000. action 1.000000. mean reward 26.989401.
# World Perf: Episode 1972.000000. Reward 13.666667. action 0.000000. mean reward 26.675489.
# World Perf: Episode 1975.000000. Reward 24.333333. action 0.000000. mean reward 26.485975.
# World Perf: Episode 1978.000000. Reward 21.333333. action 1.000000. mean reward 26.245188.
# World Perf: Episode 1981.000000. Reward 14.333333. action 0.000000. mean reward 25.954041.
# World Perf: Episode 1984.000000. Reward 17.000000. action 1.000000. mean reward 25.702271.
# World Perf: Episode 1987.000000. Reward 26.333333. action 0.000000. mean reward 25.532539.
# World Perf: Episode 1990.000000. Reward 12.000000. action 1.000000. mean reward 25.247101.
# World Perf: Episode 1993.000000. Reward 30.000000. action 1.000000. mean reward 25.128046.
# World Perf: Episode 1996.000000. Reward 26.666667. action 1.000000. mean reward 24.956030.
# World Perf: Episode 1999.000000. Reward 29.000000. action 0.000000. mean reward 24.978029.
# World Perf: Episode 2002.000000. Reward 18.666667. action 1.000000. mean reward 24.784540.
# World Perf: Episode 2005.000000. Reward 35.000000. action 1.000000. mean reward 24.947382.
# World Perf: Episode 2008.000000. Reward 13.000000. action 0.000000. mean reward 24.855288.
# World Perf: Episode 2011.000000. Reward 18.333333. action 0.000000. mean reward 24.779465.
# World Perf: Episode 2014.000000. Reward 12.333333. action 1.000000. mean reward 24.521311.
# World Perf: Episode 2017.000000. Reward 19.000000. action 0.000000. mean reward 24.342722.
# World Perf: Episode 2020.000000. Reward 27.000000. action 0.000000. mean reward 24.263391.
# World Perf: Episode 2023.000000. Reward 24.666667. action 1.000000. mean reward 24.115160.
# World Perf: Episode 2026.000000. Reward 16.000000. action 0.000000. mean reward 24.279600.
# World Perf: Episode 2029.000000. Reward 22.333333. action 1.000000. mean reward 24.557314.
# World Perf: Episode 2032.000000. Reward 17.000000. action 0.000000. mean reward 24.385149.
# World Perf: Episode 2035.000000. Reward 17.333333. action 1.000000. mean reward 24.369215.
# World Perf: Episode 2038.000000. Reward 28.666667. action 0.000000. mean reward 24.312262.
# World Perf: Episode 2041.000000. Reward 16.000000. action 1.000000. mean reward 24.124952.
# World Perf: Episode 2044.000000. Reward 19.000000. action 0.000000. mean reward 23.945930.
# World Perf: Episode 2047.000000. Reward 17.666667. action 0.000000. mean reward 23.985931.
# World Perf: Episode 2050.000000. Reward 18.333333. action 1.000000. mean reward 23.761934.
# World Perf: Episode 2053.000000. Reward 21.333333. action 0.000000. mean reward 23.627159.
# World Perf: Episode 2056.000000. Reward 29.666667. action 0.000000. mean reward 23.633684.
# World Perf: Episode 2059.000000. Reward 14.333333. action 0.000000. mean reward 23.414942.
# World Perf: Episode 2062.000000. Reward 48.333333. action 0.000000. mean reward 23.550703.
# World Perf: Episode 2065.000000. Reward 29.666667. action 0.000000. mean reward 23.535406.
# World Perf: Episode 2068.000000. Reward 30.333333. action 1.000000. mean reward 23.654274.
# World Perf: Episode 2071.000000. Reward 20.666667. action 1.000000. mean reward 23.552916.
# World Perf: Episode 2074.000000. Reward 20.000000. action 1.000000. mean reward 23.380560.
# World Perf: Episode 2077.000000. Reward 19.666667. action 1.000000. mean reward 23.499720.
# World Perf: Episode 2080.000000. Reward 22.666667. action 1.000000. mean reward 23.838030.
# World Perf: Episode 2083.000000. Reward 16.000000. action 1.000000. mean reward 23.946669.
# World Perf: Episode 2086.000000. Reward 22.000000. action 1.000000. mean reward 23.736403.
# World Perf: Episode 2089.000000. Reward 34.000000. action 0.000000. mean reward 23.719198.
# World Perf: Episode 2092.000000. Reward 28.333333. action 0.000000. mean reward 23.715425.
# World Perf: Episode 2095.000000. Reward 27.333333. action 1.000000. mean reward 23.653923.
# World Perf: Episode 2098.000000. Reward 19.666667. action 1.000000. mean reward 23.661978.
# World Perf: Episode 2101.000000. Reward 18.666667. action 1.000000. mean reward 23.610741.
# World Perf: Episode 2104.000000. Reward 20.666667. action 0.000000. mean reward 23.409693.
# World Perf: Episode 2107.000000. Reward 23.333333. action 1.000000. mean reward 23.256987.
# World Perf: Episode 2110.000000. Reward 36.000000. action 1.000000. mean reward 23.240461.
# World Perf: Episode 2113.000000. Reward 15.666667. action 1.000000. mean reward 23.023409.
# World Perf: Episode 2116.000000. Reward 23.333333. action 0.000000. mean reward 22.845350.
# World Perf: Episode 2119.000000. Reward 22.666667. action 0.000000. mean reward 22.743057.
# World Perf: Episode 2122.000000. Reward 26.333333. action 1.000000. mean reward 22.640755.
# World Perf: Episode 2125.000000. Reward 28.333333. action 0.000000. mean reward 22.551453.
# World Perf: Episode 2128.000000. Reward 23.000000. action 1.000000. mean reward 22.375559.
# World Perf: Episode 2131.000000. Reward 23.333333. action 1.000000. mean reward 22.247589.
# World Perf: Episode 2134.000000. Reward 11.666667. action 0.000000. mean reward 22.181488.
# World Perf: Episode 2137.000000. Reward 36.666667. action 0.000000. mean reward 22.579290.
# World Perf: Episode 2140.000000. Reward 14.666667. action 0.000000. mean reward 22.466866.
# World Perf: Episode 2143.000000. Reward 19.000000. action 0.000000. mean reward 22.309851.
# World Perf: Episode 2146.000000. Reward 29.000000. action 0.000000. mean reward 22.229239.
# World Perf: Episode 2149.000000. Reward 23.000000. action 1.000000. mean reward 22.299805.
# World Perf: Episode 2152.000000. Reward 15.666667. action 0.000000. mean reward 22.831108.
# World Perf: Episode 2155.000000. Reward 15.333333. action 1.000000. mean reward 23.458664.
# World Perf: Episode 2158.000000. Reward 17.666667. action 1.000000. mean reward 23.309885.
# World Perf: Episode 2161.000000. Reward 30.333333. action 0.000000. mean reward 23.421926.
# World Perf: Episode 2164.000000. Reward 17.666667. action 1.000000. mean reward 23.267540.
# World Perf: Episode 2167.000000. Reward 15.000000. action 0.000000. mean reward 23.063005.
# World Perf: Episode 2170.000000. Reward 40.333333. action 1.000000. mean reward 23.230295.
# World Perf: Episode 2173.000000. Reward 13.333333. action 0.000000. mean reward 23.314215.
# World Perf: Episode 2176.000000. Reward 23.666667. action 0.000000. mean reward 23.223463.
# World Perf: Episode 2179.000000. Reward 17.666667. action 1.000000. mean reward 23.062485.
# World Perf: Episode 2182.000000. Reward 20.666667. action 1.000000. mean reward 22.975769.
# World Perf: Episode 2185.000000. Reward 11.666667. action 0.000000. mean reward 22.820475.
# World Perf: Episode 2188.000000. Reward 19.000000. action 0.000000. mean reward 22.624342.
# World Perf: Episode 2191.000000. Reward 15.666667. action 0.000000. mean reward 22.538149.
# World Perf: Episode 2194.000000. Reward 39.000000. action 1.000000. mean reward 22.729774.
# World Perf: Episode 2197.000000. Reward 29.000000. action 1.000000. mean reward 22.692583.
# World Perf: Episode 2200.000000. Reward 25.666667. action 1.000000. mean reward 22.589724.
# World Perf: Episode 2203.000000. Reward 28.000000. action 0.000000. mean reward 22.581995.
# World Perf: Episode 2206.000000. Reward 23.000000. action 1.000000. mean reward 22.511124.
# World Perf: Episode 2209.000000. Reward 31.000000. action 0.000000. mean reward 22.648294.
# World Perf: Episode 2212.000000. Reward 32.000000. action 1.000000. mean reward 22.708445.
# World Perf: Episode 2215.000000. Reward 22.000000. action 1.000000. mean reward 22.568977.
# World Perf: Episode 2218.000000. Reward 17.666667. action 0.000000. mean reward 22.477079.
# World Perf: Episode 2221.000000. Reward 17.666667. action 1.000000. mean reward 22.304804.
# World Perf: Episode 2224.000000. Reward 15.000000. action 0.000000. mean reward 22.209459.
# World Perf: Episode 2227.000000. Reward 18.333333. action 0.000000. mean reward 22.038946.
# World Perf: Episode 2230.000000. Reward 20.000000. action 1.000000. mean reward 21.942160.
# World Perf: Episode 2233.000000. Reward 18.000000. action 1.000000. mean reward 21.929031.
# World Perf: Episode 2236.000000. Reward 15.666667. action 1.000000. mean reward 21.789824.
# World Perf: Episode 2239.000000. Reward 17.333333. action 1.000000. mean reward 21.835510.
# World Perf: Episode 2242.000000. Reward 20.666667. action 0.000000. mean reward 21.755476.
# World Perf: Episode 2245.000000. Reward 19.666667. action 0.000000. mean reward 22.955725.
# World Perf: Episode 2248.000000. Reward 17.666667. action 0.000000. mean reward 22.764265.
# World Perf: Episode 2251.000000. Reward 28.666667. action 1.000000. mean reward 22.714914.
# World Perf: Episode 2254.000000. Reward 35.666667. action 1.000000. mean reward 22.780844.
# World Perf: Episode 2257.000000. Reward 19.666667. action 0.000000. mean reward 22.663544.
# World Perf: Episode 2260.000000. Reward 12.666667. action 1.000000. mean reward 22.554144.
# World Perf: Episode 2263.000000. Reward 22.000000. action 0.000000. mean reward 22.707815.
# World Perf: Episode 2266.000000. Reward 26.666667. action 0.000000. mean reward 22.604742.
# World Perf: Episode 2269.000000. Reward 16.333333. action 1.000000. mean reward 22.436621.
# World Perf: Episode 2272.000000. Reward 17.333333. action 0.000000. mean reward 22.328407.
# World Perf: Episode 2275.000000. Reward 19.666667. action 0.000000. mean reward 22.159891.
# World Perf: Episode 2278.000000. Reward 14.333333. action 0.000000. mean reward 21.921915.
# World Perf: Episode 2281.000000. Reward 28.000000. action 0.000000. mean reward 21.922071.
# World Perf: Episode 2284.000000. Reward 16.000000. action 1.000000. mean reward 21.748171.
# World Perf: Episode 2287.000000. Reward 31.000000. action 0.000000. mean reward 21.708481.
# World Perf: Episode 2290.000000. Reward 39.333333. action 0.000000. mean reward 21.749840.
# World Perf: Episode 2293.000000. Reward 18.666667. action 1.000000. mean reward 21.728777.
#
# Real episodes is :  2293
