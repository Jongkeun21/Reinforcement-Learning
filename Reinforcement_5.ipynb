# %%
import tensorflow as tf
import numpy as np
import gym

tf.logging.set_verbosity(tf.logging.ERROR)

# %%
env = gym.make('CartPole-v0')

# %% [markdown]
# ### ***Hyper parameters***

# %%
# H: number of hidden layer neurons
# lr: learning rate
# gamma: discount factor
# D: input dimensionality(observation)

H = 10
batch_size = 5
lr = 5e-3
gamma = 0.99
D = 4

# %% [markdown]
# ### ***Training***

# %%
tf.reset_default_graph()

observations = tf.placeholder(shape=[None,D], dtype=tf.float32, name='input_x')

W1 = tf.get_variable('W1', shape=[D,H], initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations, W1))

W2 = tf.get_variable('W2', shape=[H,1], initializer=tf.contrib.layers.xavier_initializer())
score = tf.nn.relu(tf.matmul(layer1, W2))

probability = tf.nn.sigmoid(score)

tvars = tf.trainable_variables()
input_y = tf.placeholder(shape=[None,1], dtype=tf.float32, name='input_y')
advantages = tf.placeholder(dtype=tf.float32, name='reward_signal')

loglik = tf.log(input_y*(input_y-probability)+(1-input_y)*(input_y+probability))
loss = -tf.reduce_mean(loglik*advantages)
newGrads = tf.gradients(loss, tvars)

adam = tf.train.AdamOptimizer(learning_rate=lr)
W1Grad = tf.placeholder(dtype=tf.float32, name='batch_grad1')
W2Grad = tf.placeholder(dtype=tf.float32, name='batch_grad2')
batchGrad = [W1Grad, W2Grad]
updateGrad = adam.apply_gradients(zip(batchGrad, tvars))

# %% [markdown]
# ### ***Advantage function***

# %%
def discount_rewards(r) :
    discounted = np.zeros_like(r)
    running_add = 0
    
    for t in reversed(range(0, r.size)) :
        running_add = running_add*gamma+r[t]
        discounted[t] = running_add
        
    return discounted

# %% [markdown]
# ### ***Running the agent and Env***

# %%
xs, drs, ys = [], [], []
running_reward = None
reward_sum = 0
count = 1
EPOCHS = 10000
init = tf.global_variables_initializer()

with tf.Session() as sess :
    rendering = False
    sess.run(init)
    observation = env.reset()
    
    gradBuffer = sess.run(tvars)
    for idx, grad in enumerate(gradBuffer) :
        gradBuffer[idx] = grad*0
        
    while count <= EPOCHS :
        if reward_sum/batch_size > 100 or rendering :
            env.render()
            rendering = True
            
        x = np.reshape(observation, [1,D])
        
        tfprob = sess.run(probability, feed_dict={observations: x})
        action = 1 if np.random.uniform() < tfprob else 0
        
        xs.append(x)
        y = 1 if action == 0 else 0
        ys.append(y)
        
        observation, reward, done, info = env.step(action)
        reward_sum += reward
        drs.append(reward)
        
        if done :
            count += 1
            
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            xs, drs, ys = [], [], []
            
            discounted_epr = discount_rewards(epr)
            discounted_epr -= np.mean(discounted_epr)
            discounted_epr /= np.std(discounted_epr)
            
            tGrad = sess.run(newGrads, feed_dict={observations: epx, input_y: epy, advantages: discounted_epr})
            for idx, grad in enumerate(tGrad) :
                gradBuffer[idx] += grad
                
            if count%batch_size == 0 :
                sess.run(updateGrad, feed_dict={W1Grad: gradBuffer[0], W2Grad: gradBuffer[1]})
                for idx, grad in enumerate(gradBuffer) :
                    gradBuffer[idx] += grad*0
                    
                running_reward = reward_sum if running_reward is None else running_reward*0.99+reward_sum*0.01
                
                print('Average reward for episodes %.3f. Total average reward %.3f' % (reward_sum/batch_size, running_reward/batch_size))
                
                if reward_sum/batch_size > 200 :
                    print("Task solved in ", count, 'episodes.')
                    break
                    
                reward_sum = 0
                
            observation = env.reset()
            
print(count, " Episodes completed")
# Out:
# Average reward for episodes 13.000. Total average reward 13.000
# Average reward for episodes 15.000. Total average reward 13.020
# Average reward for episodes 31.800. Total average reward 13.208
# Average reward for episodes 16.400. Total average reward 13.240
# Average reward for episodes 16.200. Total average reward 13.269
# Average reward for episodes 20.400. Total average reward 13.341
# Average reward for episodes 21.000. Total average reward 13.417
# Average reward for episodes 28.800. Total average reward 13.571
# Average reward for episodes 38.600. Total average reward 13.821
# Average reward for episodes 18.200. Total average reward 13.865
# Average reward for episodes 38.200. Total average reward 14.108
# Average reward for episodes 32.400. Total average reward 14.291
# Average reward for episodes 21.800. Total average reward 14.366
# Average reward for episodes 15.600. Total average reward 14.379
# Average reward for episodes 21.000. Total average reward 14.445
# Average reward for episodes 21.400. Total average reward 14.515
# Average reward for episodes 19.800. Total average reward 14.567
# Average reward for episodes 28.200. Total average reward 14.704
# Average reward for episodes 18.800. Total average reward 14.745
# Average reward for episodes 18.800. Total average reward 14.785
# Average reward for episodes 20.400. Total average reward 14.841
# Average reward for episodes 20.400. Total average reward 14.897
# Average reward for episodes 26.200. Total average reward 15.010
# Average reward for episodes 26.600. Total average reward 15.126
# Average reward for episodes 17.800. Total average reward 15.153
# Average reward for episodes 15.200. Total average reward 15.153
# Average reward for episodes 30.000. Total average reward 15.302
# Average reward for episodes 25.800. Total average reward 15.407
# Average reward for episodes 22.200. Total average reward 15.475
# Average reward for episodes 18.200. Total average reward 15.502
# Average reward for episodes 13.000. Total average reward 15.477
# Average reward for episodes 24.800. Total average reward 15.570
# Average reward for episodes 27.200. Total average reward 15.686
# Average reward for episodes 16.600. Total average reward 15.695
# Average reward for episodes 19.800. Total average reward 15.736
# Average reward for episodes 24.400. Total average reward 15.823
# Average reward for episodes 31.600. Total average reward 15.981
# Average reward for episodes 20.200. Total average reward 16.023
# Average reward for episodes 24.800. Total average reward 16.111
# Average reward for episodes 27.600. Total average reward 16.226
# Average reward for episodes 22.600. Total average reward 16.289
# Average reward for episodes 19.400. Total average reward 16.321
# Average reward for episodes 31.600. Total average reward 16.473
# Average reward for episodes 23.600. Total average reward 16.545
# Average reward for episodes 17.600. Total average reward 16.555
# Average reward for episodes 16.000. Total average reward 16.550
# Average reward for episodes 28.000. Total average reward 16.664
# Average reward for episodes 26.200. Total average reward 16.760
# Average reward for episodes 19.200. Total average reward 16.784
# Average reward for episodes 23.800. Total average reward 16.854
# Average reward for episodes 15.200. Total average reward 16.838
# Average reward for episodes 29.800. Total average reward 16.967
# Average reward for episodes 32.200. Total average reward 17.119
# Average reward for episodes 15.600. Total average reward 17.104
# Average reward for episodes 26.000. Total average reward 17.193
# Average reward for episodes 26.800. Total average reward 17.289
# Average reward for episodes 22.400. Total average reward 17.340
# Average reward for episodes 19.600. Total average reward 17.363
# Average reward for episodes 35.400. Total average reward 17.543
# Average reward for episodes 20.400. Total average reward 17.572
# Average reward for episodes 25.200. Total average reward 17.648
# Average reward for episodes 22.400. Total average reward 17.696
# Average reward for episodes 19.000. Total average reward 17.709
# Average reward for episodes 15.400. Total average reward 17.686
# Average reward for episodes 17.600. Total average reward 17.685
# Average reward for episodes 19.400. Total average reward 17.702
# Average reward for episodes 23.600. Total average reward 17.761
# Average reward for episodes 27.600. Total average reward 17.859
# Average reward for episodes 22.800. Total average reward 17.909
# Average reward for episodes 17.800. Total average reward 17.908
# Average reward for episodes 21.400. Total average reward 17.943
# Average reward for episodes 21.200. Total average reward 17.975
# Average reward for episodes 22.600. Total average reward 18.021
# Average reward for episodes 23.800. Total average reward 18.079
# Average reward for episodes 32.600. Total average reward 18.224
# Average reward for episodes 28.400. Total average reward 18.326
# Average reward for episodes 27.000. Total average reward 18.413
# Average reward for episodes 23.000. Total average reward 18.459
# Average reward for episodes 27.800. Total average reward 18.552
# Average reward for episodes 22.000. Total average reward 18.587
# Average reward for episodes 22.200. Total average reward 18.623
# Average reward for episodes 23.600. Total average reward 18.673
# Average reward for episodes 24.600. Total average reward 18.732
# Average reward for episodes 21.600. Total average reward 18.761
# Average reward for episodes 19.400. Total average reward 18.767
# Average reward for episodes 17.200. Total average reward 18.751
# Average reward for episodes 13.800. Total average reward 18.702
# Average reward for episodes 19.400. Total average reward 18.709
# Average reward for episodes 30.400. Total average reward 18.826
# Average reward for episodes 35.800. Total average reward 18.995
# Average reward for episodes 28.200. Total average reward 19.087
# Average reward for episodes 35.400. Total average reward 19.251
# Average reward for episodes 28.800. Total average reward 19.346
# Average reward for episodes 27.200. Total average reward 19.425
# Average reward for episodes 19.200. Total average reward 19.422
# Average reward for episodes 21.000. Total average reward 19.438
# Average reward for episodes 18.000. Total average reward 19.424
# Average reward for episodes 17.000. Total average reward 19.400
# Average reward for episodes 33.600. Total average reward 19.542
# Average reward for episodes 32.600. Total average reward 19.672
# Average reward for episodes 17.600. Total average reward 19.651
# Average reward for episodes 17.400. Total average reward 19.629
# Average reward for episodes 22.600. Total average reward 19.659
# Average reward for episodes 16.600. Total average reward 19.628
# Average reward for episodes 30.600. Total average reward 19.738
# Average reward for episodes 54.800. Total average reward 20.088
# Average reward for episodes 23.200. Total average reward 20.119
# Average reward for episodes 15.000. Total average reward 20.068
# Average reward for episodes 20.800. Total average reward 20.076
# Average reward for episodes 20.200. Total average reward 20.077
# Average reward for episodes 14.800. Total average reward 20.024
# Average reward for episodes 16.400. Total average reward 19.988
# Average reward for episodes 23.200. Total average reward 20.020
# Average reward for episodes 29.400. Total average reward 20.114
# Average reward for episodes 22.600. Total average reward 20.139
# Average reward for episodes 26.000. Total average reward 20.197
# Average reward for episodes 23.000. Total average reward 20.225
# Average reward for episodes 21.800. Total average reward 20.241
# Average reward for episodes 18.800. Total average reward 20.227
# Average reward for episodes 26.400. Total average reward 20.288
# Average reward for episodes 16.800. Total average reward 20.253
# Average reward for episodes 18.400. Total average reward 20.235
# Average reward for episodes 16.600. Total average reward 20.199
# Average reward for episodes 38.200. Total average reward 20.379
# Average reward for episodes 27.000. Total average reward 20.445
# Average reward for episodes 18.800. Total average reward 20.428
# Average reward for episodes 21.800. Total average reward 20.442
# Average reward for episodes 17.600. Total average reward 20.414
# Average reward for episodes 22.800. Total average reward 20.437
# Average reward for episodes 16.200. Total average reward 20.395
# Average reward for episodes 20.800. Total average reward 20.399
# Average reward for episodes 16.000. Total average reward 20.355
# Average reward for episodes 24.000. Total average reward 20.392
# Average reward for episodes 33.600. Total average reward 20.524
# Average reward for episodes 19.800. Total average reward 20.516
# Average reward for episodes 23.600. Total average reward 20.547
# Average reward for episodes 19.800. Total average reward 20.540
# Average reward for episodes 17.200. Total average reward 20.506
# Average reward for episodes 22.800. Total average reward 20.529
# Average reward for episodes 18.400. Total average reward 20.508
# Average reward for episodes 23.000. Total average reward 20.533
# Average reward for episodes 25.400. Total average reward 20.582
# Average reward for episodes 30.200. Total average reward 20.678
# Average reward for episodes 16.800. Total average reward 20.639
# Average reward for episodes 14.600. Total average reward 20.579
# Average reward for episodes 29.200. Total average reward 20.665
# Average reward for episodes 20.600. Total average reward 20.664
# Average reward for episodes 22.400. Total average reward 20.682
# Average reward for episodes 22.200. Total average reward 20.697
# Average reward for episodes 20.400. Total average reward 20.694
# Average reward for episodes 22.000. Total average reward 20.707
# Average reward for episodes 23.800. Total average reward 20.738
# Average reward for episodes 21.000. Total average reward 20.740
# Average reward for episodes 20.200. Total average reward 20.735
# Average reward for episodes 25.400. Total average reward 20.782
# Average reward for episodes 24.600. Total average reward 20.820
# Average reward for episodes 27.400. Total average reward 20.886
# Average reward for episodes 26.200. Total average reward 20.939
# Average reward for episodes 15.200. Total average reward 20.881
# Average reward for episodes 21.200. Total average reward 20.885
# Average reward for episodes 23.600. Total average reward 20.912
# Average reward for episodes 17.000. Total average reward 20.873
# Average reward for episodes 16.800. Total average reward 20.832
# Average reward for episodes 20.600. Total average reward 20.830
# Average reward for episodes 17.600. Total average reward 20.797
# Average reward for episodes 24.800. Total average reward 20.837
# Average reward for episodes 20.400. Total average reward 20.833
# Average reward for episodes 25.400. Total average reward 20.879
# Average reward for episodes 17.400. Total average reward 20.844
# Average reward for episodes 15.800. Total average reward 20.793
# Average reward for episodes 19.600. Total average reward 20.781
# Average reward for episodes 18.800. Total average reward 20.762
# Average reward for episodes 21.400. Total average reward 20.768
# Average reward for episodes 27.000. Total average reward 20.830
# Average reward for episodes 18.600. Total average reward 20.808
# Average reward for episodes 18.400. Total average reward 20.784
# Average reward for episodes 22.400. Total average reward 20.800
# Average reward for episodes 21.400. Total average reward 20.806
# Average reward for episodes 20.800. Total average reward 20.806
# Average reward for episodes 22.000. Total average reward 20.818
# Average reward for episodes 24.600. Total average reward 20.856
# Average reward for episodes 27.200. Total average reward 20.919
# Average reward for episodes 25.400. Total average reward 20.964
# Average reward for episodes 21.200. Total average reward 20.966
# Average reward for episodes 23.000. Total average reward 20.987
# Average reward for episodes 21.200. Total average reward 20.989
# Average reward for episodes 20.800. Total average reward 20.987
# Average reward for episodes 17.400. Total average reward 20.951
# Average reward for episodes 16.000. Total average reward 20.902
# Average reward for episodes 27.200. Total average reward 20.965
# Average reward for episodes 20.800. Total average reward 20.963
# Average reward for episodes 14.600. Total average reward 20.899
# Average reward for episodes 18.200. Total average reward 20.872
# Average reward for episodes 22.000. Total average reward 20.884
# Average reward for episodes 24.400. Total average reward 20.919
# Average reward for episodes 23.800. Total average reward 20.948
# Average reward for episodes 21.400. Total average reward 20.952
# Average reward for episodes 25.400. Total average reward 20.997
# Average reward for episodes 22.800. Total average reward 21.015
# Average reward for episodes 15.400. Total average reward 20.958
# Average reward for episodes 21.400. Total average reward 20.963
# Average reward for episodes 13.600. Total average reward 20.889
# Average reward for episodes 15.200. Total average reward 20.832
# Average reward for episodes 20.000. Total average reward 20.824
# Average reward for episodes 20.600. Total average reward 20.822
# Average reward for episodes 42.000. Total average reward 21.034
# Average reward for episodes 27.200. Total average reward 21.095
# Average reward for episodes 17.000. Total average reward 21.054
# Average reward for episodes 27.200. Total average reward 21.116
# Average reward for episodes 17.600. Total average reward 21.081
# Average reward for episodes 22.400. Total average reward 21.094
# Average reward for episodes 14.800. Total average reward 21.031
# Average reward for episodes 28.200. Total average reward 21.103
# Average reward for episodes 34.800. Total average reward 21.240
# Average reward for episodes 25.400. Total average reward 21.281
# Average reward for episodes 42.200. Total average reward 21.490
# Average reward for episodes 19.600. Total average reward 21.471
# Average reward for episodes 17.600. Total average reward 21.433
# Average reward for episodes 17.200. Total average reward 21.390
# Average reward for episodes 22.200. Total average reward 21.398
# Average reward for episodes 19.400. Total average reward 21.378
# Average reward for episodes 43.800. Total average reward 21.603
# Average reward for episodes 41.400. Total average reward 21.801
# Average reward for episodes 15.200. Total average reward 21.735
# Average reward for episodes 22.200. Total average reward 21.739
# Average reward for episodes 24.600. Total average reward 21.768
# Average reward for episodes 28.000. Total average reward 21.830
# Average reward for episodes 24.600. Total average reward 21.858
# Average reward for episodes 14.000. Total average reward 21.779
# Average reward for episodes 23.600. Total average reward 21.798
# Average reward for episodes 31.600. Total average reward 21.896
# Average reward for episodes 17.400. Total average reward 21.851
# Average reward for episodes 27.600. Total average reward 21.908
# Average reward for episodes 21.200. Total average reward 21.901
# Average reward for episodes 13.400. Total average reward 21.816
# Average reward for episodes 21.200. Total average reward 21.810
# Average reward for episodes 16.000. Total average reward 21.752
# Average reward for episodes 37.400. Total average reward 21.908
# Average reward for episodes 23.800. Total average reward 21.927
# Average reward for episodes 45.400. Total average reward 22.162
# Average reward for episodes 19.400. Total average reward 22.134
# Average reward for episodes 22.600. Total average reward 22.139
# Average reward for episodes 14.000. Total average reward 22.058
# Average reward for episodes 21.000. Total average reward 22.047
# Average reward for episodes 50.000. Total average reward 22.327
# Average reward for episodes 22.800. Total average reward 22.331
# Average reward for episodes 33.600. Total average reward 22.444
# Average reward for episodes 36.400. Total average reward 22.583
# Average reward for episodes 29.600. Total average reward 22.654
# Average reward for episodes 24.200. Total average reward 22.669
# Average reward for episodes 21.200. Total average reward 22.654
# Average reward for episodes 25.600. Total average reward 22.684
# Average reward for episodes 36.000. Total average reward 22.817
# Average reward for episodes 22.400. Total average reward 22.813
# Average reward for episodes 24.400. Total average reward 22.829
# Average reward for episodes 29.400. Total average reward 22.894
# Average reward for episodes 42.400. Total average reward 23.090
# Average reward for episodes 29.200. Total average reward 23.151
# Average reward for episodes 46.200. Total average reward 23.381
# Average reward for episodes 30.800. Total average reward 23.455
# Average reward for episodes 33.800. Total average reward 23.559
# Average reward for episodes 35.200. Total average reward 23.675
# Average reward for episodes 33.400. Total average reward 23.772
# Average reward for episodes 42.200. Total average reward 23.957
# Average reward for episodes 39.000. Total average reward 24.107
# Average reward for episodes 20.600. Total average reward 24.072
# Average reward for episodes 41.600. Total average reward 24.247
# Average reward for episodes 36.800. Total average reward 24.373
# Average reward for episodes 17.400. Total average reward 24.303
# Average reward for episodes 44.800. Total average reward 24.508
# Average reward for episodes 39.400. Total average reward 24.657
# Average reward for episodes 42.200. Total average reward 24.832
# Average reward for episodes 53.600. Total average reward 25.120
# Average reward for episodes 35.000. Total average reward 25.219
# Average reward for episodes 19.000. Total average reward 25.157
# Average reward for episodes 43.200. Total average reward 25.337
# Average reward for episodes 44.000. Total average reward 25.524
# Average reward for episodes 31.400. Total average reward 25.583
# Average reward for episodes 33.600. Total average reward 25.663
# Average reward for episodes 30.200. Total average reward 25.708
# Average reward for episodes 23.400. Total average reward 25.685
# Average reward for episodes 45.000. Total average reward 25.878
# Average reward for episodes 42.400. Total average reward 26.043
# Average reward for episodes 27.400. Total average reward 26.057
# Average reward for episodes 31.400. Total average reward 26.110
# Average reward for episodes 28.600. Total average reward 26.135
# Average reward for episodes 29.400. Total average reward 26.168
# Average reward for episodes 54.000. Total average reward 26.446
# Average reward for episodes 32.800. Total average reward 26.510
# Average reward for episodes 72.000. Total average reward 26.965
# Average reward for episodes 25.400. Total average reward 26.949
# Average reward for episodes 36.000. Total average reward 27.040
# Average reward for episodes 40.800. Total average reward 27.177
# Average reward for episodes 27.600. Total average reward 27.181
# Average reward for episodes 38.600. Total average reward 27.296
# Average reward for episodes 22.600. Total average reward 27.249
# Average reward for episodes 22.000. Total average reward 27.196
# Average reward for episodes 28.200. Total average reward 27.206
# Average reward for episodes 44.000. Total average reward 27.374
# Average reward for episodes 31.400. Total average reward 27.414
# Average reward for episodes 37.800. Total average reward 27.518
# Average reward for episodes 24.400. Total average reward 27.487
# Average reward for episodes 43.400. Total average reward 27.646
# Average reward for episodes 38.800. Total average reward 27.758
# Average reward for episodes 31.800. Total average reward 27.798
# Average reward for episodes 36.400. Total average reward 27.884
# Average reward for episodes 46.800. Total average reward 28.073
# Average reward for episodes 35.400. Total average reward 28.147
# Average reward for episodes 39.800. Total average reward 28.263
# Average reward for episodes 20.400. Total average reward 28.184
# Average reward for episodes 32.000. Total average reward 28.223
# Average reward for episodes 41.200. Total average reward 28.352
# Average reward for episodes 31.800. Total average reward 28.387
# Average reward for episodes 25.000. Total average reward 28.353
# Average reward for episodes 32.000. Total average reward 28.389
# Average reward for episodes 21.000. Total average reward 28.316
# Average reward for episodes 21.800. Total average reward 28.250
# Average reward for episodes 28.000. Total average reward 28.248
# Average reward for episodes 23.400. Total average reward 28.199
# Average reward for episodes 31.200. Total average reward 28.229
# Average reward for episodes 20.000. Total average reward 28.147
# Average reward for episodes 24.800. Total average reward 28.114
# Average reward for episodes 27.600. Total average reward 28.109
# Average reward for episodes 19.800. Total average reward 28.025
# Average reward for episodes 33.800. Total average reward 28.083
# Average reward for episodes 40.800. Total average reward 28.210
# Average reward for episodes 26.000. Total average reward 28.188
# Average reward for episodes 20.400. Total average reward 28.110
# Average reward for episodes 24.000. Total average reward 28.069
# Average reward for episodes 34.000. Total average reward 28.129
# Average reward for episodes 29.800. Total average reward 28.145
# Average reward for episodes 29.600. Total average reward 28.160
# Average reward for episodes 30.000. Total average reward 28.178
# Average reward for episodes 30.400. Total average reward 28.200
# Average reward for episodes 26.800. Total average reward 28.186
# Average reward for episodes 24.600. Total average reward 28.151
# Average reward for episodes 23.000. Total average reward 28.099
# Average reward for episodes 25.200. Total average reward 28.070
# Average reward for episodes 23.400. Total average reward 28.023
# Average reward for episodes 23.000. Total average reward 27.973
# Average reward for episodes 34.600. Total average reward 28.039
# Average reward for episodes 50.000. Total average reward 28.259
# Average reward for episodes 28.000. Total average reward 28.256
# Average reward for episodes 28.000. Total average reward 28.254
# Average reward for episodes 34.200. Total average reward 28.313
# Average reward for episodes 27.400. Total average reward 28.304
# Average reward for episodes 25.600. Total average reward 28.277
# Average reward for episodes 20.400. Total average reward 28.198
# Average reward for episodes 39.000. Total average reward 28.306
# Average reward for episodes 31.400. Total average reward 28.337
# Average reward for episodes 26.200. Total average reward 28.316
# Average reward for episodes 40.200. Total average reward 28.435
# Average reward for episodes 27.800. Total average reward 28.428
# Average reward for episodes 30.400. Total average reward 28.448
# Average reward for episodes 26.200. Total average reward 28.426
# Average reward for episodes 19.800. Total average reward 28.339
# Average reward for episodes 17.200. Total average reward 28.228
# Average reward for episodes 31.000. Total average reward 28.256
# Average reward for episodes 22.000. Total average reward 28.193
# Average reward for episodes 18.000. Total average reward 28.091
# Average reward for episodes 24.200. Total average reward 28.052
# Average reward for episodes 21.200. Total average reward 27.984
# Average reward for episodes 33.000. Total average reward 28.034
# Average reward for episodes 29.600. Total average reward 28.050
# Average reward for episodes 19.400. Total average reward 27.963
# Average reward for episodes 25.000. Total average reward 27.934
# Average reward for episodes 31.200. Total average reward 27.966
# Average reward for episodes 24.600. Total average reward 27.933
# Average reward for episodes 47.000. Total average reward 28.123
# Average reward for episodes 30.400. Total average reward 28.146
# Average reward for episodes 27.600. Total average reward 28.141
# Average reward for episodes 20.600. Total average reward 28.065
# Average reward for episodes 21.400. Total average reward 27.998
# Average reward for episodes 23.800. Total average reward 27.956
# Average reward for episodes 28.000. Total average reward 27.957
# Average reward for episodes 21.600. Total average reward 27.893
# Average reward for episodes 21.400. Total average reward 27.828
# Average reward for episodes 19.800. Total average reward 27.748
# Average reward for episodes 23.200. Total average reward 27.703
# Average reward for episodes 31.000. Total average reward 27.736
# Average reward for episodes 18.600. Total average reward 27.644
# Average reward for episodes 21.800. Total average reward 27.586
# Average reward for episodes 27.000. Total average reward 27.580
# Average reward for episodes 35.600. Total average reward 27.660
# Average reward for episodes 30.000. Total average reward 27.684
# Average reward for episodes 30.000. Total average reward 27.707
# Average reward for episodes 24.000. Total average reward 27.670
# Average reward for episodes 18.600. Total average reward 27.579
# Average reward for episodes 20.600. Total average reward 27.509
# Average reward for episodes 32.200. Total average reward 27.556
# Average reward for episodes 17.200. Total average reward 27.453
# Average reward for episodes 26.800. Total average reward 27.446
# Average reward for episodes 30.400. Total average reward 27.476
# Average reward for episodes 17.800. Total average reward 27.379
# Average reward for episodes 18.000. Total average reward 27.285
# Average reward for episodes 24.400. Total average reward 27.256
# Average reward for episodes 29.800. Total average reward 27.282
# Average reward for episodes 22.200. Total average reward 27.231
# Average reward for episodes 26.000. Total average reward 27.218
# Average reward for episodes 18.000. Total average reward 27.126
# Average reward for episodes 21.000. Total average reward 27.065
# Average reward for episodes 22.400. Total average reward 27.018
# Average reward for episodes 22.200. Total average reward 26.970
# Average reward for episodes 26.200. Total average reward 26.962
# Average reward for episodes 28.400. Total average reward 26.977
# Average reward for episodes 25.400. Total average reward 26.961
# Average reward for episodes 26.800. Total average reward 26.959
# Average reward for episodes 28.800. Total average reward 26.978
# Average reward for episodes 30.400. Total average reward 27.012
# Average reward for episodes 34.000. Total average reward 27.082
# Average reward for episodes 22.800. Total average reward 27.039
# Average reward for episodes 33.400. Total average reward 27.103
# Average reward for episodes 30.000. Total average reward 27.132
# Average reward for episodes 28.400. Total average reward 27.144
# Average reward for episodes 27.600. Total average reward 27.149
# Average reward for episodes 21.800. Total average reward 27.095
# Average reward for episodes 31.200. Total average reward 27.137
# Average reward for episodes 24.800. Total average reward 27.113
# Average reward for episodes 34.200. Total average reward 27.184
# Average reward for episodes 27.600. Total average reward 27.188
# Average reward for episodes 30.200. Total average reward 27.218
# Average reward for episodes 33.600. Total average reward 27.282
# Average reward for episodes 21.600. Total average reward 27.225
# Average reward for episodes 22.600. Total average reward 27.179
# Average reward for episodes 26.000. Total average reward 27.167
# Average reward for episodes 36.400. Total average reward 27.260
# Average reward for episodes 24.200. Total average reward 27.229
# Average reward for episodes 26.000. Total average reward 27.217
# Average reward for episodes 17.600. Total average reward 27.121
# Average reward for episodes 25.200. Total average reward 27.101
# Average reward for episodes 17.800. Total average reward 27.008
# Average reward for episodes 22.600. Total average reward 26.964
# Average reward for episodes 29.400. Total average reward 26.989
# Average reward for episodes 23.200. Total average reward 26.951
# Average reward for episodes 20.600. Total average reward 26.887
# Average reward for episodes 21.000. Total average reward 26.828
# Average reward for episodes 32.000. Total average reward 26.880
# Average reward for episodes 23.200. Total average reward 26.843
# Average reward for episodes 30.800. Total average reward 26.883
# Average reward for episodes 29.000. Total average reward 26.904
# Average reward for episodes 20.200. Total average reward 26.837
# Average reward for episodes 22.800. Total average reward 26.797
# Average reward for episodes 20.200. Total average reward 26.731
# Average reward for episodes 29.600. Total average reward 26.759
# Average reward for episodes 24.800. Total average reward 26.740
# Average reward for episodes 18.000. Total average reward 26.652
# Average reward for episodes 45.600. Total average reward 26.842
# Average reward for episodes 27.400. Total average reward 26.847
# Average reward for episodes 20.200. Total average reward 26.781
# Average reward for episodes 18.600. Total average reward 26.699
# Average reward for episodes 31.800. Total average reward 26.750
# Average reward for episodes 25.000. Total average reward 26.733
# Average reward for episodes 29.800. Total average reward 26.763
# Average reward for episodes 24.400. Total average reward 26.740
# Average reward for episodes 21.000. Total average reward 26.682
# Average reward for episodes 28.600. Total average reward 26.701
# Average reward for episodes 28.600. Total average reward 26.720
# Average reward for episodes 18.600. Total average reward 26.639
# Average reward for episodes 32.400. Total average reward 26.697
# Average reward for episodes 37.600. Total average reward 26.806
# Average reward for episodes 32.000. Total average reward 26.858
# Average reward for episodes 27.800. Total average reward 26.867
# Average reward for episodes 32.200. Total average reward 26.921
# Average reward for episodes 25.000. Total average reward 26.901
# Average reward for episodes 30.000. Total average reward 26.932
# Average reward for episodes 29.000. Total average reward 26.953
# Average reward for episodes 23.800. Total average reward 26.921
# Average reward for episodes 26.200. Total average reward 26.914
# Average reward for episodes 34.800. Total average reward 26.993
# Average reward for episodes 35.000. Total average reward 27.073
# Average reward for episodes 19.000. Total average reward 26.992
# Average reward for episodes 27.600. Total average reward 26.999
# Average reward for episodes 26.000. Total average reward 26.989
# Average reward for episodes 18.000. Total average reward 26.899
# Average reward for episodes 30.600. Total average reward 26.936
# Average reward for episodes 38.200. Total average reward 27.048
# Average reward for episodes 32.200. Total average reward 27.100
# Average reward for episodes 14.800. Total average reward 26.977
# Average reward for episodes 17.400. Total average reward 26.881
# Average reward for episodes 26.400. Total average reward 26.876
# Average reward for episodes 23.200. Total average reward 26.839
# Average reward for episodes 28.200. Total average reward 26.853
# Average reward for episodes 24.800. Total average reward 26.833
# Average reward for episodes 22.200. Total average reward 26.786
# Average reward for episodes 29.400. Total average reward 26.812
# Average reward for episodes 28.400. Total average reward 26.828
# Average reward for episodes 43.600. Total average reward 26.996
# Average reward for episodes 28.800. Total average reward 27.014
# Average reward for episodes 42.600. Total average reward 27.170
# Average reward for episodes 34.000. Total average reward 27.238
# Average reward for episodes 34.800. Total average reward 27.314
# Average reward for episodes 30.800. Total average reward 27.349
# Average reward for episodes 26.400. Total average reward 27.339
# Average reward for episodes 34.400. Total average reward 27.410
# Average reward for episodes 20.600. Total average reward 27.342
# Average reward for episodes 29.000. Total average reward 27.358
# Average reward for episodes 18.000. Total average reward 27.265
# Average reward for episodes 24.200. Total average reward 27.234
# Average reward for episodes 23.800. Total average reward 27.200
# Average reward for episodes 23.000. Total average reward 27.158
# Average reward for episodes 24.800. Total average reward 27.134
# Average reward for episodes 29.200. Total average reward 27.155
# Average reward for episodes 26.600. Total average reward 27.149
# Average reward for episodes 34.600. Total average reward 27.224
# Average reward for episodes 33.800. Total average reward 27.289
# Average reward for episodes 15.000. Total average reward 27.167
# Average reward for episodes 24.800. Total average reward 27.143
# Average reward for episodes 18.400. Total average reward 27.056
# Average reward for episodes 24.200. Total average reward 27.027
# Average reward for episodes 19.800. Total average reward 26.955
# Average reward for episodes 24.400. Total average reward 26.929
# Average reward for episodes 25.800. Total average reward 26.918
# Average reward for episodes 29.000. Total average reward 26.939
# Average reward for episodes 30.400. Total average reward 26.973
# Average reward for episodes 30.200. Total average reward 27.006
# Average reward for episodes 32.600. Total average reward 27.061
# Average reward for episodes 26.000. Total average reward 27.051
# Average reward for episodes 32.000. Total average reward 27.100
# Average reward for episodes 27.800. Total average reward 27.107
# Average reward for episodes 21.000. Total average reward 27.046
# Average reward for episodes 23.600. Total average reward 27.012
# Average reward for episodes 22.800. Total average reward 26.970
# Average reward for episodes 15.800. Total average reward 26.858
# Average reward for episodes 31.400. Total average reward 26.903
# Average reward for episodes 21.800. Total average reward 26.852
# Average reward for episodes 20.200. Total average reward 26.786
# Average reward for episodes 24.200. Total average reward 26.760
# Average reward for episodes 16.200. Total average reward 26.654
# Average reward for episodes 15.400. Total average reward 26.542
# Average reward for episodes 40.000. Total average reward 26.676
# Average reward for episodes 22.800. Total average reward 26.638
# Average reward for episodes 27.600. Total average reward 26.647
# Average reward for episodes 31.800. Total average reward 26.699
# Average reward for episodes 30.800. Total average reward 26.740
# Average reward for episodes 30.600. Total average reward 26.778
# Average reward for episodes 36.400. Total average reward 26.875
# Average reward for episodes 37.000. Total average reward 26.976
# Average reward for episodes 14.400. Total average reward 26.850
# Average reward for episodes 36.200. Total average reward 26.944
# Average reward for episodes 39.800. Total average reward 27.072
# Average reward for episodes 22.200. Total average reward 27.023
# Average reward for episodes 26.400. Total average reward 27.017
# Average reward for episodes 41.600. Total average reward 27.163
# Average reward for episodes 24.200. Total average reward 27.133
# Average reward for episodes 25.200. Total average reward 27.114
# Average reward for episodes 20.000. Total average reward 27.043
# Average reward for episodes 31.800. Total average reward 27.091
# Average reward for episodes 21.200. Total average reward 27.032
# Average reward for episodes 26.600. Total average reward 27.027
# Average reward for episodes 30.800. Total average reward 27.065
# Average reward for episodes 30.800. Total average reward 27.102
# Average reward for episodes 28.600. Total average reward 27.117
# Average reward for episodes 24.800. Total average reward 27.094
# Average reward for episodes 34.800. Total average reward 27.171
# Average reward for episodes 26.000. Total average reward 27.160
# Average reward for episodes 27.600. Total average reward 27.164
# Average reward for episodes 23.000. Total average reward 27.122
# Average reward for episodes 33.800. Total average reward 27.189
# Average reward for episodes 25.600. Total average reward 27.173
# Average reward for episodes 26.400. Total average reward 27.165
# Average reward for episodes 29.000. Total average reward 27.184
# Average reward for episodes 18.800. Total average reward 27.100
# Average reward for episodes 28.800. Total average reward 27.117
# Average reward for episodes 29.200. Total average reward 27.138
# Average reward for episodes 31.600. Total average reward 27.182
# Average reward for episodes 18.200. Total average reward 27.093
# Average reward for episodes 27.800. Total average reward 27.100
# Average reward for episodes 25.400. Total average reward 27.083
# Average reward for episodes 28.200. Total average reward 27.094
# Average reward for episodes 25.400. Total average reward 27.077
# Average reward for episodes 34.800. Total average reward 27.154
# Average reward for episodes 40.400. Total average reward 27.287
# Average reward for episodes 21.800. Total average reward 27.232
# Average reward for episodes 32.000. Total average reward 27.279
# Average reward for episodes 20.400. Total average reward 27.211
# Average reward for episodes 29.000. Total average reward 27.229
# Average reward for episodes 23.200. Total average reward 27.188
# Average reward for episodes 51.600. Total average reward 27.432
# Average reward for episodes 37.000. Total average reward 27.528
# Average reward for episodes 35.000. Total average reward 27.603
# Average reward for episodes 28.200. Total average reward 27.609
# Average reward for episodes 22.200. Total average reward 27.555
# Average reward for episodes 29.000. Total average reward 27.569
# Average reward for episodes 37.000. Total average reward 27.663
# Average reward for episodes 29.200. Total average reward 27.679
# Average reward for episodes 21.600. Total average reward 27.618
# Average reward for episodes 22.600. Total average reward 27.568
# Average reward for episodes 18.800. Total average reward 27.480
# Average reward for episodes 28.200. Total average reward 27.487
# Average reward for episodes 28.400. Total average reward 27.496
# Average reward for episodes 25.000. Total average reward 27.471
# Average reward for episodes 19.800. Total average reward 27.395
# Average reward for episodes 22.600. Total average reward 27.347
# Average reward for episodes 23.400. Total average reward 27.307
# Average reward for episodes 23.600. Total average reward 27.270
# Average reward for episodes 54.000. Total average reward 27.538
# Average reward for episodes 21.200. Total average reward 27.474
# Average reward for episodes 28.200. Total average reward 27.481
# Average reward for episodes 20.000. Total average reward 27.407
# Average reward for episodes 37.200. Total average reward 27.505
# Average reward for episodes 17.400. Total average reward 27.404
# Average reward for episodes 28.400. Total average reward 27.413
# Average reward for episodes 27.200. Total average reward 27.411
# Average reward for episodes 26.000. Total average reward 27.397
# Average reward for episodes 36.200. Total average reward 27.485
# Average reward for episodes 21.600. Total average reward 27.426
# Average reward for episodes 30.000. Total average reward 27.452
# Average reward for episodes 28.800. Total average reward 27.466
# Average reward for episodes 29.000. Total average reward 27.481
# Average reward for episodes 19.800. Total average reward 27.404
# Average reward for episodes 31.600. Total average reward 27.446
# Average reward for episodes 30.400. Total average reward 27.476
# Average reward for episodes 29.000. Total average reward 27.491
# Average reward for episodes 26.200. Total average reward 27.478
# Average reward for episodes 22.400. Total average reward 27.427
# Average reward for episodes 23.600. Total average reward 27.389
# Average reward for episodes 27.000. Total average reward 27.385
# Average reward for episodes 31.200. Total average reward 27.423
# Average reward for episodes 19.000. Total average reward 27.339
# Average reward for episodes 45.600. Total average reward 27.522
# Average reward for episodes 31.000. Total average reward 27.556
# Average reward for episodes 36.800. Total average reward 27.649
# Average reward for episodes 33.800. Total average reward 27.710
# Average reward for episodes 26.000. Total average reward 27.693
# Average reward for episodes 46.800. Total average reward 27.884
# Average reward for episodes 29.200. Total average reward 27.897
# Average reward for episodes 35.800. Total average reward 27.976
# Average reward for episodes 22.400. Total average reward 27.921
# Average reward for episodes 44.400. Total average reward 28.085
# Average reward for episodes 17.600. Total average reward 27.981
# Average reward for episodes 33.000. Total average reward 28.031
# Average reward for episodes 23.800. Total average reward 27.989
# Average reward for episodes 19.800. Total average reward 27.907
# Average reward for episodes 36.600. Total average reward 27.994
# Average reward for episodes 20.000. Total average reward 27.914
# Average reward for episodes 29.600. Total average reward 27.931
# Average reward for episodes 24.600. Total average reward 27.897
# Average reward for episodes 29.800. Total average reward 27.916
# Average reward for episodes 27.800. Total average reward 27.915
# Average reward for episodes 24.400. Total average reward 27.880
# Average reward for episodes 23.000. Total average reward 27.831
# Average reward for episodes 29.000. Total average reward 27.843
# Average reward for episodes 49.400. Total average reward 28.058
# Average reward for episodes 34.400. Total average reward 28.122
# Average reward for episodes 20.000. Total average reward 28.041
# Average reward for episodes 38.400. Total average reward 28.144
# Average reward for episodes 30.600. Total average reward 28.169
# Average reward for episodes 25.400. Total average reward 28.141
# Average reward for episodes 27.600. Total average reward 28.136
# Average reward for episodes 40.400. Total average reward 28.258
# Average reward for episodes 28.800. Total average reward 28.264
# Average reward for episodes 25.600. Total average reward 28.237
# Average reward for episodes 32.200. Total average reward 28.277
# Average reward for episodes 30.200. Total average reward 28.296
# Average reward for episodes 42.600. Total average reward 28.439
# Average reward for episodes 19.400. Total average reward 28.349
# Average reward for episodes 20.800. Total average reward 28.273
# Average reward for episodes 18.200. Total average reward 28.172
# Average reward for episodes 27.400. Total average reward 28.165
# Average reward for episodes 19.800. Total average reward 28.081
# Average reward for episodes 30.000. Total average reward 28.100
# Average reward for episodes 16.600. Total average reward 27.985
# Average reward for episodes 35.200. Total average reward 28.057
# Average reward for episodes 21.200. Total average reward 27.989
# Average reward for episodes 16.000. Total average reward 27.869
# Average reward for episodes 29.000. Total average reward 27.880
# Average reward for episodes 25.400. Total average reward 27.855
# Average reward for episodes 43.800. Total average reward 28.015
# Average reward for episodes 28.600. Total average reward 28.021
# Average reward for episodes 18.800. Total average reward 27.928
# Average reward for episodes 32.400. Total average reward 27.973
# Average reward for episodes 22.200. Total average reward 27.915
# Average reward for episodes 19.400. Total average reward 27.830
# Average reward for episodes 23.400. Total average reward 27.786
# Average reward for episodes 33.400. Total average reward 27.842
# Average reward for episodes 20.400. Total average reward 27.768
# Average reward for episodes 20.000. Total average reward 27.690
# Average reward for episodes 33.600. Total average reward 27.749
# Average reward for episodes 36.600. Total average reward 27.838
# Average reward for episodes 43.400. Total average reward 27.993
# Average reward for episodes 34.600. Total average reward 28.059
# Average reward for episodes 30.200. Total average reward 28.081
# Average reward for episodes 27.800. Total average reward 28.078
# Average reward for episodes 26.400. Total average reward 28.061
# Average reward for episodes 23.400. Total average reward 28.015
# Average reward for episodes 31.400. Total average reward 28.048
# Average reward for episodes 35.000. Total average reward 28.118
# Average reward for episodes 20.000. Total average reward 28.037
# Average reward for episodes 22.400. Total average reward 27.980
# Average reward for episodes 33.800. Total average reward 28.039
# Average reward for episodes 42.200. Total average reward 28.180
# Average reward for episodes 22.800. Total average reward 28.126
# Average reward for episodes 29.200. Total average reward 28.137
# Average reward for episodes 25.800. Total average reward 28.114
# Average reward for episodes 27.400. Total average reward 28.107
# Average reward for episodes 49.400. Total average reward 28.320
# Average reward for episodes 24.600. Total average reward 28.282
# Average reward for episodes 39.000. Total average reward 28.390
# Average reward for episodes 34.200. Total average reward 28.448
# Average reward for episodes 29.000. Total average reward 28.453
# Average reward for episodes 30.200. Total average reward 28.471
# Average reward for episodes 37.800. Total average reward 28.564
# Average reward for episodes 34.200. Total average reward 28.620
# Average reward for episodes 34.400. Total average reward 28.678
# Average reward for episodes 37.800. Total average reward 28.769
# Average reward for episodes 22.400. Total average reward 28.706
# Average reward for episodes 41.000. Total average reward 28.829
# Average reward for episodes 29.600. Total average reward 28.836
# Average reward for episodes 33.200. Total average reward 28.880
# Average reward for episodes 43.200. Total average reward 29.023
# Average reward for episodes 39.400. Total average reward 29.127
# Average reward for episodes 46.000. Total average reward 29.296
# Average reward for episodes 39.600. Total average reward 29.399
# Average reward for episodes 26.400. Total average reward 29.369
# Average reward for episodes 33.400. Total average reward 29.409
# Average reward for episodes 35.400. Total average reward 29.469
# Average reward for episodes 29.200. Total average reward 29.466
# Average reward for episodes 29.800. Total average reward 29.470
# Average reward for episodes 25.000. Total average reward 29.425
# Average reward for episodes 29.000. Total average reward 29.421
# Average reward for episodes 24.000. Total average reward 29.366
# Average reward for episodes 29.400. Total average reward 29.367
# Average reward for episodes 34.000. Total average reward 29.413
# Average reward for episodes 15.400. Total average reward 29.273
# Average reward for episodes 25.000. Total average reward 29.230
# Average reward for episodes 29.800. Total average reward 29.236
# Average reward for episodes 32.600. Total average reward 29.270
# Average reward for episodes 31.400. Total average reward 29.291
# Average reward for episodes 50.200. Total average reward 29.500
# Average reward for episodes 46.600. Total average reward 29.671
# Average reward for episodes 30.600. Total average reward 29.680
# Average reward for episodes 26.800. Total average reward 29.651
# Average reward for episodes 22.400. Total average reward 29.579
# Average reward for episodes 18.800. Total average reward 29.471
# Average reward for episodes 38.600. Total average reward 29.562
# Average reward for episodes 19.400. Total average reward 29.461
# Average reward for episodes 46.600. Total average reward 29.632
# Average reward for episodes 26.800. Total average reward 29.604
# Average reward for episodes 26.400. Total average reward 29.572
# Average reward for episodes 26.200. Total average reward 29.538
# Average reward for episodes 50.800. Total average reward 29.751
# Average reward for episodes 33.800. Total average reward 29.791
# Average reward for episodes 21.600. Total average reward 29.709
# Average reward for episodes 17.200. Total average reward 29.584
# Average reward for episodes 26.800. Total average reward 29.556
# Average reward for episodes 30.600. Total average reward 29.567
# Average reward for episodes 23.200. Total average reward 29.503
# Average reward for episodes 25.800. Total average reward 29.466
# Average reward for episodes 19.000. Total average reward 29.361
# Average reward for episodes 37.200. Total average reward 29.440
# ...
# Average reward for episodes 41.200. Total average reward 27.327
# Average reward for episodes 26.800. Total average reward 27.322
# Average reward for episodes 21.600. Total average reward 27.265
# Average reward for episodes 24.200. Total average reward 27.234
# Average reward for episodes 24.800. Total average reward 27.210
# Average reward for episodes 50.600. Total average reward 27.444
# Average reward for episodes 43.000. Total average reward 27.599
# Average reward for episodes 24.400. Total average reward 27.567
# Average reward for episodes 34.600. Total average reward 27.637
# Average reward for episodes 47.400. Total average reward 27.835
# Average reward for episodes 15.800. Total average reward 27.715
# Average reward for episodes 37.800. Total average reward 27.816
# Average reward for episodes 37.800. Total average reward 27.915
# Average reward for episodes 55.800. Total average reward 28.194
# Average reward for episodes 21.800. Total average reward 28.130
# Average reward for episodes 21.000. Total average reward 28.059
# Average reward for episodes 44.200. Total average reward 28.220
# Average reward for episodes 36.200. Total average reward 28.300
# Average reward for episodes 21.800. Total average reward 28.235
# Average reward for episodes 23.200. Total average reward 28.185
# Average reward for episodes 43.400. Total average reward 28.337
# Average reward for episodes 22.000. Total average reward 28.274
# Average reward for episodes 30.200. Total average reward 28.293
# Average reward for episodes 24.600. Total average reward 28.256
# Average reward for episodes 25.400. Total average reward 28.227
# Average reward for episodes 24.400. Total average reward 28.189
# Average reward for episodes 21.800. Total average reward 28.125
# Average reward for episodes 21.000. Total average reward 28.054
# Average reward for episodes 28.400. Total average reward 28.057
# Average reward for episodes 21.200. Total average reward 27.989
# Average reward for episodes 38.400. Total average reward 28.093
# Average reward for episodes 26.000. Total average reward 28.072
# Average reward for episodes 22.800. Total average reward 28.019
# Average reward for episodes 39.800. Total average reward 28.137
# Average reward for episodes 23.200. Total average reward 28.088
# Average reward for episodes 30.400. Total average reward 28.111
# Average reward for episodes 19.200. Total average reward 28.022
# Average reward for episodes 36.400. Total average reward 28.106
# Average reward for episodes 44.000. Total average reward 28.265
# Average reward for episodes 28.400. Total average reward 28.266
# Average reward for episodes 26.400. Total average reward 28.247
# Average reward for episodes 21.000. Total average reward 28.175
# Average reward for episodes 36.600. Total average reward 28.259
# Average reward for episodes 23.400. Total average reward 28.210
# Average reward for episodes 20.000. Total average reward 28.128
# Average reward for episodes 37.000. Total average reward 28.217
# Average reward for episodes 34.600. Total average reward 28.281
# Average reward for episodes 30.600. Total average reward 28.304
# Average reward for episodes 39.000. Total average reward 28.411
# Average reward for episodes 24.400. Total average reward 28.371
# Average reward for episodes 23.400. Total average reward 28.321
# Average reward for episodes 33.600. Total average reward 28.374
# Average reward for episodes 20.000. Total average reward 28.290
# Average reward for episodes 20.400. Total average reward 28.211
# Average reward for episodes 19.600. Total average reward 28.125
# Average reward for episodes 12.800. Total average reward 27.972
# Average reward for episodes 36.400. Total average reward 28.056
# Average reward for episodes 44.000. Total average reward 28.216
# Average reward for episodes 20.400. Total average reward 28.138
# Average reward for episodes 19.800. Total average reward 28.054
# Average reward for episodes 35.600. Total average reward 28.130
# Average reward for episodes 24.000. Total average reward 28.088
# Average reward for episodes 32.000. Total average reward 28.127
# Average reward for episodes 16.600. Total average reward 28.012
# Average reward for episodes 30.800. Total average reward 28.040
# Average reward for episodes 25.200. Total average reward 28.012
# Average reward for episodes 31.200. Total average reward 28.044
# Average reward for episodes 32.200. Total average reward 28.085
# Average reward for episodes 27.000. Total average reward 28.074
# Average reward for episodes 26.200. Total average reward 28.056
# Average reward for episodes 33.200. Total average reward 28.107
# Average reward for episodes 39.400. Total average reward 28.220
# Average reward for episodes 24.400. Total average reward 28.182
# Average reward for episodes 31.000. Total average reward 28.210
# Average reward for episodes 32.000. Total average reward 28.248
# Average reward for episodes 24.000. Total average reward 28.205
# Average reward for episodes 21.800. Total average reward 28.141
# Average reward for episodes 23.600. Total average reward 28.096
# Average reward for episodes 35.200. Total average reward 28.167
# Average reward for episodes 31.800. Total average reward 28.203
# Average reward for episodes 21.400. Total average reward 28.135
# Average reward for episodes 39.200. Total average reward 28.246
# Average reward for episodes 21.000. Total average reward 28.173
# Average reward for episodes 19.400. Total average reward 28.086
# Average reward for episodes 26.200. Total average reward 28.067
# Average reward for episodes 42.800. Total average reward 28.214
# Average reward for episodes 32.800. Total average reward 28.260
# Average reward for episodes 21.400. Total average reward 28.191
# Average reward for episodes 21.600. Total average reward 28.125
# Average reward for episodes 30.000. Total average reward 28.144
# Average reward for episodes 52.600. Total average reward 28.389
# Average reward for episodes 18.600. Total average reward 28.291
# Average reward for episodes 25.200. Total average reward 28.260
# Average reward for episodes 22.000. Total average reward 28.197
# Average reward for episodes 48.800. Total average reward 28.403
# Average reward for episodes 48.600. Total average reward 28.605
# Average reward for episodes 18.400. Total average reward 28.503
# Average reward for episodes 28.000. Total average reward 28.498
# Average reward for episodes 46.000. Total average reward 28.673
# Average reward for episodes 21.200. Total average reward 28.599
# Average reward for episodes 31.400. Total average reward 28.627
# Average reward for episodes 35.000. Total average reward 28.690
# Average reward for episodes 29.800. Total average reward 28.701
# Average reward for episodes 29.000. Total average reward 28.704
# Average reward for episodes 26.200. Total average reward 28.679
# Average reward for episodes 19.800. Total average reward 28.591
# Average reward for episodes 33.000. Total average reward 28.635
# Average reward for episodes 20.200. Total average reward 28.550
# Average reward for episodes 19.800. Total average reward 28.463
# Average reward for episodes 20.200. Total average reward 28.380
# Average reward for episodes 18.200. Total average reward 28.278
# Average reward for episodes 25.400. Total average reward 28.250
# Average reward for episodes 28.800. Total average reward 28.255
# Average reward for episodes 26.200. Total average reward 28.235
# Average reward for episodes 20.400. Total average reward 28.156
# Average reward for episodes 39.200. Total average reward 28.267
# Average reward for episodes 30.000. Total average reward 28.284
# Average reward for episodes 39.200. Total average reward 28.393
# Average reward for episodes 30.400. Total average reward 28.413
# Average reward for episodes 32.400. Total average reward 28.453
# Average reward for episodes 23.400. Total average reward 28.403
# Average reward for episodes 20.600. Total average reward 28.324
# Average reward for episodes 23.800. Total average reward 28.279
# Average reward for episodes 25.600. Total average reward 28.252
# Average reward for episodes 17.600. Total average reward 28.146
# Average reward for episodes 17.800. Total average reward 28.042
# Average reward for episodes 39.200. Total average reward 28.154
# Average reward for episodes 30.600. Total average reward 28.179
# Average reward for episodes 34.200. Total average reward 28.239
# Average reward for episodes 24.400. Total average reward 28.200
# Average reward for episodes 24.400. Total average reward 28.162
# Average reward for episodes 22.000. Total average reward 28.101
# Average reward for episodes 28.600. Total average reward 28.106
# Average reward for episodes 36.200. Total average reward 28.187
# Average reward for episodes 21.200. Total average reward 28.117
# Average reward for episodes 34.200. Total average reward 28.178
# Average reward for episodes 27.800. Total average reward 28.174
# Average reward for episodes 17.400. Total average reward 28.066
# Average reward for episodes 36.000. Total average reward 28.145
# Average reward for episodes 28.000. Total average reward 28.144
# Average reward for episodes 34.800. Total average reward 28.211
# Average reward for episodes 24.600. Total average reward 28.174
# Average reward for episodes 26.200. Total average reward 28.155
# Average reward for episodes 30.400. Total average reward 28.177
# Average reward for episodes 20.800. Total average reward 28.103
# Average reward for episodes 23.600. Total average reward 28.058
# Average reward for episodes 16.200. Total average reward 27.940
# Average reward for episodes 31.400. Total average reward 27.974
# Average reward for episodes 27.200. Total average reward 27.967
# Average reward for episodes 36.800. Total average reward 28.055
# Average reward for episodes 49.800. Total average reward 28.272
# Average reward for episodes 21.200. Total average reward 28.202
# Average reward for episodes 17.400. Total average reward 28.094
# Average reward for episodes 19.200. Total average reward 28.005
# Average reward for episodes 33.200. Total average reward 28.057
# Average reward for episodes 20.200. Total average reward 27.978
# Average reward for episodes 24.400. Total average reward 27.942
# Average reward for episodes 27.000. Total average reward 27.933
# Average reward for episodes 32.400. Total average reward 27.978
# Average reward for episodes 19.600. Total average reward 27.894
# Average reward for episodes 17.000. Total average reward 27.785
# Average reward for episodes 16.200. Total average reward 27.669
# Average reward for episodes 15.600. Total average reward 27.548
# Average reward for episodes 37.600. Total average reward 27.649
# Average reward for episodes 26.000. Total average reward 27.632
# Average reward for episodes 45.600. Total average reward 27.812
# Average reward for episodes 18.600. Total average reward 27.720
# Average reward for episodes 32.600. Total average reward 27.769
# Average reward for episodes 32.000. Total average reward 27.811
# Average reward for episodes 42.400. Total average reward 27.957
# Average reward for episodes 34.200. Total average reward 28.019
# Average reward for episodes 29.200. Total average reward 28.031
# Average reward for episodes 22.800. Total average reward 27.979
# Average reward for episodes 18.200. Total average reward 27.881
# Average reward for episodes 31.800. Total average reward 27.920
# Average reward for episodes 27.600. Total average reward 27.917
# Average reward for episodes 37.200. Total average reward 28.010
# Average reward for episodes 36.800. Total average reward 28.098
# Average reward for episodes 38.600. Total average reward 28.203
# Average reward for episodes 32.600. Total average reward 28.247
# Average reward for episodes 33.400. Total average reward 28.298
# Average reward for episodes 21.800. Total average reward 28.233
# Average reward for episodes 17.600. Total average reward 28.127
# Average reward for episodes 31.200. Total average reward 28.158
# Average reward for episodes 30.800. Total average reward 28.184
# Average reward for episodes 29.200. Total average reward 28.194
# Average reward for episodes 24.800. Total average reward 28.160
# Average reward for episodes 30.800. Total average reward 28.187
# Average reward for episodes 20.800. Total average reward 28.113
# Average reward for episodes 20.600. Total average reward 28.038
# Average reward for episodes 25.400. Total average reward 28.011
# Average reward for episodes 23.000. Total average reward 27.961
# Average reward for episodes 24.600. Total average reward 27.928
# Average reward for episodes 18.600. Total average reward 27.834
# Average reward for episodes 36.400. Total average reward 27.920
# Average reward for episodes 22.400. Total average reward 27.865
# Average reward for episodes 31.600. Total average reward 27.902
# Average reward for episodes 20.600. Total average reward 27.829
# Average reward for episodes 23.800. Total average reward 27.789
# Average reward for episodes 19.600. Total average reward 27.707
# Average reward for episodes 23.200. Total average reward 27.662
# Average reward for episodes 42.200. Total average reward 27.807
# Average reward for episodes 31.000. Total average reward 27.839
# Average reward for episodes 26.000. Total average reward 27.821
# Average reward for episodes 28.000. Total average reward 27.823
# Average reward for episodes 16.800. Total average reward 27.712
# Average reward for episodes 24.800. Total average reward 27.683
# Average reward for episodes 28.000. Total average reward 27.686
# Average reward for episodes 15.400. Total average reward 27.564
# Average reward for episodes 32.200. Total average reward 27.610
# Average reward for episodes 22.200. Total average reward 27.556
# Average reward for episodes 38.400. Total average reward 27.664
# Average reward for episodes 23.600. Total average reward 27.624
# Average reward for episodes 35.000. Total average reward 27.697
# Average reward for episodes 28.400. Total average reward 27.704
# Average reward for episodes 29.200. Total average reward 27.719
# Average reward for episodes 19.600. Total average reward 27.638
# Average reward for episodes 14.600. Total average reward 27.508
# Average reward for episodes 24.200. Total average reward 27.475
# Average reward for episodes 31.200. Total average reward 27.512
# Average reward for episodes 19.800. Total average reward 27.435
# Average reward for episodes 33.400. Total average reward 27.495
# Average reward for episodes 25.400. Total average reward 27.474
# Average reward for episodes 15.400. Total average reward 27.353
# Average reward for episodes 30.800. Total average reward 27.387
# Average reward for episodes 26.400. Total average reward 27.377
# Average reward for episodes 21.400. Total average reward 27.318
# Average reward for episodes 37.000. Total average reward 27.414
# Average reward for episodes 26.000. Total average reward 27.400
# Average reward for episodes 38.200. Total average reward 27.508
# Average reward for episodes 19.200. Total average reward 27.425
# Average reward for episodes 27.600. Total average reward 27.427
# Average reward for episodes 23.600. Total average reward 27.389
# Average reward for episodes 29.200. Total average reward 27.407
# Average reward for episodes 46.000. Total average reward 27.593
# Average reward for episodes 21.400. Total average reward 27.531
# Average reward for episodes 24.600. Total average reward 27.502
# Average reward for episodes 23.600. Total average reward 27.463
# Average reward for episodes 44.000. Total average reward 27.628
# Average reward for episodes 16.400. Total average reward 27.516
# Average reward for episodes 35.600. Total average reward 27.596
# Average reward for episodes 26.400. Total average reward 27.584
# Average reward for episodes 21.400. Total average reward 27.523
# Average reward for episodes 24.200. Total average reward 27.489
# Average reward for episodes 33.800. Total average reward 27.553
# Average reward for episodes 23.600. Total average reward 27.513
# Average reward for episodes 30.000. Total average reward 27.538
# Average reward for episodes 33.800. Total average reward 27.600
# Average reward for episodes 49.600. Total average reward 27.820
# 10001  Episodes completed
